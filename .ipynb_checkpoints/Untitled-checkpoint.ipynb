# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from teslaver import utilities as utls
from loclust import parse


    

    matplotlib.use('Qt5Agg') #use Qt5 as backend, comment this line for default backend
    
    df = utls.trajectories_to_dataframe(trajs=parse.read_trajectories(path_to_trajectories))
    groo_X = df.groupby('X')
    ylim = (min(df['Y']),max(df['Y']))
    xlim = (min(groo_X.groups.keys()), max(groo_X.groups.keys()))
    fig = plt.figure()
    ax = plt.axes(xlim=xlim, ylim=ylim)
    
    
    
    
    
    
    num_lines = len(df.groupby(distinct_entry_tag).groups.keys())
    
    
    
    lines = [plt.plot([],[])[0] for _ in range(num_lines-1)]
    
    frame_count = len(groo_X.groups.keys())
    
    anim = animation.FuncAnimation(fig=fig, func=animate, fargs=[distinct_entry_tag, df, lines], frames=None, blit=True)
    HTML(anim.to_html5_video())
#     anim.save('graaaph.mp4', writer=writer)
def initee(lines)

def animatee(i, distinct_entry_tag, df, lines):
    groo_DET = df.groupby(distinct_entry_tag)
    for index, line in enumerate(groo.groups.keys()):
        lines[index].set_data(groo.get_group(line)['X'][i],groo.get_group(line)['Y'][i])
    return lines












plot_graph(path_to_trajectories='./data/CO2_trajs.csv', 
           xaxis_title='test', yaxis_title ='ytest', title = 'hi',
           distinct_entry_tag='country_name')
# Out:
# ...reading data
# 4
# 0
# Southern Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 34.0
# ISO 3166-2:AF
# EN.ATM.CO2E.PP.GD
# Afghanistan
# Southern Asia
# AF
# AFG
# 8
# 1
# Southern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 39.0
# ISO 3166-2:AL
# EN.ATM.CO2E.PP.GD
# Albania
# Southern Europe
# AL
# ALB
# 12
# 2
# Northern Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 15.0
# ISO 3166-2:DZ
# EN.ATM.CO2E.PP.GD
# Algeria
# Northern Africa
# DZ
# DZA
# 24
# 3
# Middle Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 17.0
# ISO 3166-2:AO
# EN.ATM.CO2E.PP.GD
# Angola
# Middle Africa
# AO
# AGO
# 28
# 4
# Caribbean
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 29.0
# ISO 3166-2:AG
# EN.ATM.CO2E.PP.GD
# Antigua and Barbuda
# Caribbean
# AG
# ATG
# 32
# 5
# South America
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 5.0
# ISO 3166-2:AR
# EN.ATM.CO2E.PP.GD
# Argentina
# South America
# AR
# ARG
# 51
# 6
# Western Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 145.0
# ISO 3166-2:AM
# EN.ATM.CO2E.PP.GD
# Armenia
# Western Asia
# AM
# ARM
# 36
# 7
# Australia and New Zealand
# Oceania
# CO2 emissions (kg per PPP $ of GDP)
# 9.0
# 53.0
# ISO 3166-2:AU
# EN.ATM.CO2E.PP.GD
# Australia
# Australia and New Zealand
# AU
# AUS
# 40
# 8
# Western Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 155.0
# ISO 3166-2:AT
# EN.ATM.CO2E.PP.GD
# Austria
# Western Europe
# AT
# AUT
# 31
# 6
# Western Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 145.0
# ISO 3166-2:AZ
# EN.ATM.CO2E.PP.GD
# Azerbaijan
# Western Asia
# AZ
# AZE
# 44
# 4
# Caribbean
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 29.0
# ISO 3166-2:BS
# EN.ATM.CO2E.PP.GD
# Bahamas, The
# Caribbean
# BS
# BHS
# 48
# 6
# Western Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 145.0
# ISO 3166-2:BH
# EN.ATM.CO2E.PP.GD
# Bahrain
# Western Asia
# BH
# BHR
# 50
# 0
# Southern Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 34.0
# ISO 3166-2:BD
# EN.ATM.CO2E.PP.GD
# Bangladesh
# Southern Asia
# BD
# BGD
# 52
# 4
# Caribbean
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 29.0
# ISO 3166-2:BB
# EN.ATM.CO2E.PP.GD
# Barbados
# Caribbean
# BB
# BRB
# 112
# 9
# Eastern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 151.0
# ISO 3166-2:BY
# EN.ATM.CO2E.PP.GD
# Belarus
# Eastern Europe
# BY
# BLR
# 56
# 8
# Western Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 155.0
# ISO 3166-2:BE
# EN.ATM.CO2E.PP.GD
# Belgium
# Western Europe
# BE
# BEL
# 84
# 10
# Central America
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 13.0
# ISO 3166-2:BZ
# EN.ATM.CO2E.PP.GD
# Belize
# Central America
# BZ
# BLZ
# 204
# 11
# Western Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 11.0
# ISO 3166-2:BJ
# EN.ATM.CO2E.PP.GD
# Benin
# Western Africa
# BJ
# BEN
# 60
# 12
# Northern America
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 21.0
# ISO 3166-2:BM
# EN.ATM.CO2E.PP.GD
# Bermuda
# Northern America
# BM
# BMU
# 64
# 0
# Southern Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 34.0
# ISO 3166-2:BT
# EN.ATM.CO2E.PP.GD
# Bhutan
# Southern Asia
# BT
# BTN
# 68
# 5
# South America
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 5.0
# ISO 3166-2:BO
# EN.ATM.CO2E.PP.GD
# Bolivia
# South America
# BO
# BOL
# 70
# 1
# Southern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 39.0
# ISO 3166-2:BA
# EN.ATM.CO2E.PP.GD
# Bosnia and Herzegovina
# Southern Europe
# BA
# BIH
# 72
# 13
# Southern Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 18.0
# ISO 3166-2:BW
# EN.ATM.CO2E.PP.GD
# Botswana
# Southern Africa
# BW
# BWA
# 76
# 5
# South America
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 5.0
# ISO 3166-2:BR
# EN.ATM.CO2E.PP.GD
# Brazil
# South America
# BR
# BRA
# 96
# 14
# South-Eastern Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 35.0
# ISO 3166-2:BN
# EN.ATM.CO2E.PP.GD
# Brunei Darussalam
# South-Eastern Asia
# BN
# BRN
# 100
# 9
# Eastern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 151.0
# ISO 3166-2:BG
# EN.ATM.CO2E.PP.GD
# Bulgaria
# Eastern Europe
# BG
# BGR
# 854
# 11
# Western Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 11.0
# ISO 3166-2:BF
# EN.ATM.CO2E.PP.GD
# Burkina Faso
# Western Africa
# BF
# BFA
# 108
# 15
# Eastern Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 14.0
# ISO 3166-2:BI
# EN.ATM.CO2E.PP.GD
# Burundi
# Eastern Africa
# BI
# BDI
# 132
# 11
# Western Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 11.0
# ISO 3166-2:CV
# EN.ATM.CO2E.PP.GD
# Cabo Verde
# Western Africa
# CV
# CPV
# 116
# 14
# South-Eastern Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 35.0
# ISO 3166-2:KH
# EN.ATM.CO2E.PP.GD
# Cambodia
# South-Eastern Asia
# KH
# KHM
# 120
# 3
# Middle Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 17.0
# ISO 3166-2:CM
# EN.ATM.CO2E.PP.GD
# Cameroon
# Middle Africa
# CM
# CMR
# 124
# 12
# Northern America
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 21.0
# ISO 3166-2:CA
# EN.ATM.CO2E.PP.GD
# Canada
# Northern America
# CA
# CAN
# 140
# 3
# Middle Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 17.0
# ISO 3166-2:CF
# EN.ATM.CO2E.PP.GD
# Central African Republic
# Middle Africa
# CF
# CAF
# 148
# 3
# Middle Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 17.0
# ISO 3166-2:TD
# EN.ATM.CO2E.PP.GD
# Chad
# Middle Africa
# TD
# TCD
# 152
# 5
# South America
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 5.0
# ISO 3166-2:CL
# EN.ATM.CO2E.PP.GD
# Chile
# South America
# CL
# CHL
# 156
# 16
# Eastern Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 30.0
# ISO 3166-2:CN
# EN.ATM.CO2E.PP.GD
# China
# Eastern Asia
# CN
# CHN
# 170
# 5
# South America
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 5.0
# ISO 3166-2:CO
# EN.ATM.CO2E.PP.GD
# Colombia
# South America
# CO
# COL
# 174
# 15
# Eastern Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 14.0
# ISO 3166-2:KM
# EN.ATM.CO2E.PP.GD
# Comoros
# Eastern Africa
# KM
# COM
# 180
# 3
# Middle Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 17.0
# ISO 3166-2:CD
# EN.ATM.CO2E.PP.GD
# Congo, Dem. Rep.
# Middle Africa
# CD
# COD
# 178
# 3
# Middle Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 17.0
# ISO 3166-2:CG
# EN.ATM.CO2E.PP.GD
# Congo, Rep.
# Middle Africa
# CG
# COG
# 188
# 10
# Central America
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 13.0
# ISO 3166-2:CR
# EN.ATM.CO2E.PP.GD
# Costa Rica
# Central America
# CR
# CRI
# 384
# 11
# Western Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 11.0
# ISO 3166-2:CI
# EN.ATM.CO2E.PP.GD
# Cote d'Ivoire
# Western Africa
# CI
# CIV
# 191
# 1
# Southern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 39.0
# ISO 3166-2:HR
# EN.ATM.CO2E.PP.GD
# Croatia
# Southern Europe
# HR
# HRV
# 196
# 6
# Western Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 145.0
# ISO 3166-2:CY
# EN.ATM.CO2E.PP.GD
# Cyprus
# Western Asia
# CY
# CYP
# 203
# 9
# Eastern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 151.0
# ISO 3166-2:CZ
# EN.ATM.CO2E.PP.GD
# Czech Republic
# Eastern Europe
# CZ
# CZE
# 208
# 17
# Northern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 154.0
# ISO 3166-2:DK
# EN.ATM.CO2E.PP.GD
# Denmark
# Northern Europe
# DK
# DNK
# 262
# 15
# Eastern Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 14.0
# ISO 3166-2:DJ
# EN.ATM.CO2E.PP.GD
# Djibouti
# Eastern Africa
# DJ
# DJI
# 212
# 4
# Caribbean
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 29.0
# ISO 3166-2:DM
# EN.ATM.CO2E.PP.GD
# Dominica
# Caribbean
# DM
# DMA
# 214
# 4
# Caribbean
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 29.0
# ISO 3166-2:DO
# EN.ATM.CO2E.PP.GD
# Dominican Republic
# Caribbean
# DO
# DOM
# 218
# 5
# South America
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 5.0
# ISO 3166-2:EC
# EN.ATM.CO2E.PP.GD
# Ecuador
# South America
# EC
# ECU
# 818
# 2
# Northern Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 15.0
# ISO 3166-2:EG
# EN.ATM.CO2E.PP.GD
# Egypt, Arab Rep.
# Northern Africa
# EG
# EGY
# 222
# 10
# Central America
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 13.0
# ISO 3166-2:SV
# EN.ATM.CO2E.PP.GD
# El Salvador
# Central America
# SV
# SLV
# 226
# 3
# Middle Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 17.0
# ISO 3166-2:GQ
# EN.ATM.CO2E.PP.GD
# Equatorial Guinea
# Middle Africa
# GQ
# GNQ
# 232
# 15
# Eastern Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 14.0
# ISO 3166-2:ER
# EN.ATM.CO2E.PP.GD
# Eritrea
# Eastern Africa
# ER
# ERI
# 233
# 17
# Northern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 154.0
# ISO 3166-2:EE
# EN.ATM.CO2E.PP.GD
# Estonia
# Northern Europe
# EE
# EST
# 231
# 15
# Eastern Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 14.0
# ISO 3166-2:ET
# EN.ATM.CO2E.PP.GD
# Ethiopia
# Eastern Africa
# ET
# ETH
# 242
# 18
# Melanesia
# Oceania
# CO2 emissions (kg per PPP $ of GDP)
# 9.0
# 54.0
# ISO 3166-2:FJ
# EN.ATM.CO2E.PP.GD
# Fiji
# Melanesia
# FJ
# FJI
# 246
# 17
# Northern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 154.0
# ISO 3166-2:FI
# EN.ATM.CO2E.PP.GD
# Finland
# Northern Europe
# FI
# FIN
# 250
# 8
# Western Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 155.0
# ISO 3166-2:FR
# EN.ATM.CO2E.PP.GD
# France
# Western Europe
# FR
# FRA
# 266
# 3
# Middle Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 17.0
# ISO 3166-2:GA
# EN.ATM.CO2E.PP.GD
# Gabon
# Middle Africa
# GA
# GAB
# 270
# 11
# Western Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 11.0
# ISO 3166-2:GM
# EN.ATM.CO2E.PP.GD
# Gambia, The
# Western Africa
# GM
# GMB
# 268
# 6
# Western Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 145.0
# ISO 3166-2:GE
# EN.ATM.CO2E.PP.GD
# Georgia
# Western Asia
# GE
# GEO
# 276
# 8
# Western Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 155.0
# ISO 3166-2:DE
# EN.ATM.CO2E.PP.GD
# Germany
# Western Europe
# DE
# DEU
# 288
# 11
# Western Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 11.0
# ISO 3166-2:GH
# EN.ATM.CO2E.PP.GD
# Ghana
# Western Africa
# GH
# GHA
# 300
# 1
# Southern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 39.0
# ISO 3166-2:GR
# EN.ATM.CO2E.PP.GD
# Greece
# Southern Europe
# GR
# GRC
# 308
# 4
# Caribbean
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 29.0
# ISO 3166-2:GD
# EN.ATM.CO2E.PP.GD
# Grenada
# Caribbean
# GD
# GRD
# 320
# 10
# Central America
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 13.0
# ISO 3166-2:GT
# EN.ATM.CO2E.PP.GD
# Guatemala
# Central America
# GT
# GTM
# 324
# 11
# Western Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 11.0
# ISO 3166-2:GN
# EN.ATM.CO2E.PP.GD
# Guinea
# Western Africa
# GN
# GIN
# 624
# 11
# Western Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 11.0
# ISO 3166-2:GW
# EN.ATM.CO2E.PP.GD
# Guinea-Bissau
# Western Africa
# GW
# GNB
# 328
# 5
# South America
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 5.0
# ISO 3166-2:GY
# EN.ATM.CO2E.PP.GD
# Guyana
# South America
# GY
# GUY
# 332
# 4
# Caribbean
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 29.0
# ISO 3166-2:HT
# EN.ATM.CO2E.PP.GD
# Haiti
# Caribbean
# HT
# HTI
# 340
# 10
# Central America
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 13.0
# ISO 3166-2:HN
# EN.ATM.CO2E.PP.GD
# Honduras
# Central America
# HN
# HND
# 344
# 16
# Eastern Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 30.0
# ISO 3166-2:HK
# EN.ATM.CO2E.PP.GD
# Hong Kong SAR, China
# Eastern Asia
# HK
# HKG
# 348
# 9
# Eastern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 151.0
# ISO 3166-2:HU
# EN.ATM.CO2E.PP.GD
# Hungary
# Eastern Europe
# HU
# HUN
# 352
# 17
# Northern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 154.0
# ISO 3166-2:IS
# EN.ATM.CO2E.PP.GD
# Iceland
# Northern Europe
# IS
# ISL
# 356
# 0
# Southern Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 34.0
# ISO 3166-2:IN
# EN.ATM.CO2E.PP.GD
# India
# Southern Asia
# IN
# IND
# 360
# 14
# South-Eastern Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 35.0
# ISO 3166-2:ID
# EN.ATM.CO2E.PP.GD
# Indonesia
# South-Eastern Asia
# ID
# IDN
# 364
# 0
# Southern Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 34.0
# ISO 3166-2:IR
# EN.ATM.CO2E.PP.GD
# Iran, Islamic Rep.
# Southern Asia
# IR
# IRN
# 368
# 6
# Western Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 145.0
# ISO 3166-2:IQ
# EN.ATM.CO2E.PP.GD
# Iraq
# Western Asia
# IQ
# IRQ
# 372
# 17
# Northern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 154.0
# ISO 3166-2:IE
# EN.ATM.CO2E.PP.GD
# Ireland
# Northern Europe
# IE
# IRL
# 376
# 6
# Western Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 145.0
# ISO 3166-2:IL
# EN.ATM.CO2E.PP.GD
# Israel
# Western Asia
# IL
# ISR
# 380
# 1
# Southern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 39.0
# ISO 3166-2:IT
# EN.ATM.CO2E.PP.GD
# Italy
# Southern Europe
# IT
# ITA
# 388
# 4
# Caribbean
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 29.0
# ISO 3166-2:JM
# EN.ATM.CO2E.PP.GD
# Jamaica
# Caribbean
# JM
# JAM
# 392
# 16
# Eastern Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 30.0
# ISO 3166-2:JP
# EN.ATM.CO2E.PP.GD
# Japan
# Eastern Asia
# JP
# JPN
# 400
# 6
# Western Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 145.0
# ISO 3166-2:JO
# EN.ATM.CO2E.PP.GD
# Jordan
# Western Asia
# JO
# JOR
# 398
# 19
# Central Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 143.0
# ISO 3166-2:KZ
# EN.ATM.CO2E.PP.GD
# Kazakhstan
# Central Asia
# KZ
# KAZ
# 404
# 15
# Eastern Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 14.0
# ISO 3166-2:KE
# EN.ATM.CO2E.PP.GD
# Kenya
# Eastern Africa
# KE
# KEN
# 296
# 20
# Micronesia
# Oceania
# CO2 emissions (kg per PPP $ of GDP)
# 9.0
# 57.0
# ISO 3166-2:KI
# EN.ATM.CO2E.PP.GD
# Kiribati
# Micronesia
# KI
# KIR
# 410
# 16
# Eastern Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 30.0
# ISO 3166-2:KR
# EN.ATM.CO2E.PP.GD
# Korea, Rep.
# Eastern Asia
# KR
# KOR
# 414
# 6
# Western Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 145.0
# ISO 3166-2:KW
# EN.ATM.CO2E.PP.GD
# Kuwait
# Western Asia
# KW
# KWT
# 417
# 19
# Central Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 143.0
# ISO 3166-2:KG
# EN.ATM.CO2E.PP.GD
# Kyrgyz Republic
# Central Asia
# KG
# KGZ
# 418
# 14
# South-Eastern Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 35.0
# ISO 3166-2:LA
# EN.ATM.CO2E.PP.GD
# Lao PDR
# South-Eastern Asia
# LA
# LAO
# 428
# 17
# Northern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 154.0
# ISO 3166-2:LV
# EN.ATM.CO2E.PP.GD
# Latvia
# Northern Europe
# LV
# LVA
# 422
# 6
# Western Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 145.0
# ISO 3166-2:LB
# EN.ATM.CO2E.PP.GD
# Lebanon
# Western Asia
# LB
# LBN
# 426
# 13
# Southern Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 18.0
# ISO 3166-2:LS
# EN.ATM.CO2E.PP.GD
# Lesotho
# Southern Africa
# LS
# LSO
# 430
# 11
# Western Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 11.0
# ISO 3166-2:LR
# EN.ATM.CO2E.PP.GD
# Liberia
# Western Africa
# LR
# LBR
# 434
# 2
# Northern Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 15.0
# ISO 3166-2:LY
# EN.ATM.CO2E.PP.GD
# Libya
# Northern Africa
# LY
# LBY
# 440
# 17
# Northern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 154.0
# ISO 3166-2:LT
# EN.ATM.CO2E.PP.GD
# Lithuania
# Northern Europe
# LT
# LTU
# 442
# 8
# Western Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 155.0
# ISO 3166-2:LU
# EN.ATM.CO2E.PP.GD
# Luxembourg
# Western Europe
# LU
# LUX
# 446
# 16
# Eastern Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 30.0
# ISO 3166-2:MO
# EN.ATM.CO2E.PP.GD
# Macao SAR, China
# Eastern Asia
# MO
# MAC
# 807
# 1
# Southern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 39.0
# ISO 3166-2:MK
# EN.ATM.CO2E.PP.GD
# Macedonia, FYR
# Southern Europe
# MK
# MKD
# 450
# 15
# Eastern Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 14.0
# ISO 3166-2:MG
# EN.ATM.CO2E.PP.GD
# Madagascar
# Eastern Africa
# MG
# MDG
# 454
# 15
# Eastern Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 14.0
# ISO 3166-2:MW
# EN.ATM.CO2E.PP.GD
# Malawi
# Eastern Africa
# MW
# MWI
# 458
# 14
# South-Eastern Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 35.0
# ISO 3166-2:MY
# EN.ATM.CO2E.PP.GD
# Malaysia
# South-Eastern Asia
# MY
# MYS
# 462
# 0
# Southern Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 34.0
# ISO 3166-2:MV
# EN.ATM.CO2E.PP.GD
# Maldives
# Southern Asia
# MV
# MDV
# 466
# 11
# Western Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 11.0
# ISO 3166-2:ML
# EN.ATM.CO2E.PP.GD
# Mali
# Western Africa
# ML
# MLI
# 470
# 1
# Southern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 39.0
# ISO 3166-2:MT
# EN.ATM.CO2E.PP.GD
# Malta
# Southern Europe
# MT
# MLT
# 584
# 20
# Micronesia
# Oceania
# CO2 emissions (kg per PPP $ of GDP)
# 9.0
# 57.0
# ISO 3166-2:MH
# EN.ATM.CO2E.PP.GD
# Marshall Islands
# Micronesia
# MH
# MHL
# 478
# 11
# Western Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 11.0
# ISO 3166-2:MR
# EN.ATM.CO2E.PP.GD
# Mauritania
# Western Africa
# MR
# MRT
# 480
# 15
# Eastern Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 14.0
# ISO 3166-2:MU
# EN.ATM.CO2E.PP.GD
# Mauritius
# Eastern Africa
# MU
# MUS
# 484
# 10
# Central America
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 13.0
# ISO 3166-2:MX
# EN.ATM.CO2E.PP.GD
# Mexico
# Central America
# MX
# MEX
# 583
# 20
# Micronesia
# Oceania
# CO2 emissions (kg per PPP $ of GDP)
# 9.0
# 57.0
# ISO 3166-2:FM
# EN.ATM.CO2E.PP.GD
# Micronesia, Fed. Sts.
# Micronesia
# FM
# FSM
# 498
# 9
# Eastern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 151.0
# ISO 3166-2:MD
# EN.ATM.CO2E.PP.GD
# Moldova
# Eastern Europe
# MD
# MDA
# 496
# 16
# Eastern Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 30.0
# ISO 3166-2:MN
# EN.ATM.CO2E.PP.GD
# Mongolia
# Eastern Asia
# MN
# MNG
# 499
# 1
# Southern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 39.0
# ISO 3166-2:ME
# EN.ATM.CO2E.PP.GD
# Montenegro
# Southern Europe
# ME
# MNE
# 504
# 2
# Northern Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 15.0
# ISO 3166-2:MA
# EN.ATM.CO2E.PP.GD
# Morocco
# Northern Africa
# MA
# MAR
# 508
# 15
# Eastern Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 14.0
# ISO 3166-2:MZ
# EN.ATM.CO2E.PP.GD
# Mozambique
# Eastern Africa
# MZ
# MOZ
# 104
# 14
# South-Eastern Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 35.0
# ISO 3166-2:MM
# EN.ATM.CO2E.PP.GD
# Myanmar
# South-Eastern Asia
# MM
# MMR
# 516
# 13
# Southern Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 18.0
# ISO 3166-2:NA
# EN.ATM.CO2E.PP.GD
# Namibia
# Southern Africa
# nan
# NAM
# 524
# 0
# Southern Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 34.0
# ISO 3166-2:NP
# EN.ATM.CO2E.PP.GD
# Nepal
# Southern Asia
# NP
# NPL
# 528
# 8
# Western Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 155.0
# ISO 3166-2:NL
# EN.ATM.CO2E.PP.GD
# Netherlands
# Western Europe
# NL
# NLD
# 554
# 7
# Australia and New Zealand
# Oceania
# CO2 emissions (kg per PPP $ of GDP)
# 9.0
# 53.0
# ISO 3166-2:NZ
# EN.ATM.CO2E.PP.GD
# New Zealand
# Australia and New Zealand
# NZ
# NZL
# 558
# 10
# Central America
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 13.0
# ISO 3166-2:NI
# EN.ATM.CO2E.PP.GD
# Nicaragua
# Central America
# NI
# NIC
# 562
# 11
# Western Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 11.0
# ISO 3166-2:NE
# EN.ATM.CO2E.PP.GD
# Niger
# Western Africa
# NE
# NER
# 566
# 11
# Western Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 11.0
# ISO 3166-2:NG
# EN.ATM.CO2E.PP.GD
# Nigeria
# Western Africa
# NG
# NGA
# 578
# 17
# Northern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 154.0
# ISO 3166-2:NO
# EN.ATM.CO2E.PP.GD
# Norway
# Northern Europe
# NO
# NOR
# 512
# 6
# Western Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 145.0
# ISO 3166-2:OM
# EN.ATM.CO2E.PP.GD
# Oman
# Western Asia
# OM
# OMN
# 586
# 0
# Southern Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 34.0
# ISO 3166-2:PK
# EN.ATM.CO2E.PP.GD
# Pakistan
# Southern Asia
# PK
# PAK
# 585
# 20
# Micronesia
# Oceania
# CO2 emissions (kg per PPP $ of GDP)
# 9.0
# 57.0
# ISO 3166-2:PW
# EN.ATM.CO2E.PP.GD
# Palau
# Micronesia
# PW
# PLW
# 591
# 10
# Central America
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 13.0
# ISO 3166-2:PA
# EN.ATM.CO2E.PP.GD
# Panama
# Central America
# PA
# PAN
# 598
# 18
# Melanesia
# Oceania
# CO2 emissions (kg per PPP $ of GDP)
# 9.0
# 54.0
# ISO 3166-2:PG
# EN.ATM.CO2E.PP.GD
# Papua New Guinea
# Melanesia
# PG
# PNG
# 600
# 5
# South America
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 5.0
# ISO 3166-2:PY
# EN.ATM.CO2E.PP.GD
# Paraguay
# South America
# PY
# PRY
# 604
# 5
# South America
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 5.0
# ISO 3166-2:PE
# EN.ATM.CO2E.PP.GD
# Peru
# South America
# PE
# PER
# 608
# 14
# South-Eastern Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 35.0
# ISO 3166-2:PH
# EN.ATM.CO2E.PP.GD
# Philippines
# South-Eastern Asia
# PH
# PHL
# 616
# 9
# Eastern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 151.0
# ISO 3166-2:PL
# EN.ATM.CO2E.PP.GD
# Poland
# Eastern Europe
# PL
# POL
# 620
# 1
# Southern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 39.0
# ISO 3166-2:PT
# EN.ATM.CO2E.PP.GD
# Portugal
# Southern Europe
# PT
# PRT
# 634
# 6
# Western Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 145.0
# ISO 3166-2:QA
# EN.ATM.CO2E.PP.GD
# Qatar
# Western Asia
# QA
# QAT
# 642
# 9
# Eastern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 151.0
# ISO 3166-2:RO
# EN.ATM.CO2E.PP.GD
# Romania
# Eastern Europe
# RO
# ROU
# 643
# 9
# Eastern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 151.0
# ISO 3166-2:RU
# EN.ATM.CO2E.PP.GD
# Russian Federation
# Eastern Europe
# RU
# RUS
# 646
# 15
# Eastern Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 14.0
# ISO 3166-2:RW
# EN.ATM.CO2E.PP.GD
# Rwanda
# Eastern Africa
# RW
# RWA
# 882
# 21
# Polynesia
# Oceania
# CO2 emissions (kg per PPP $ of GDP)
# 9.0
# 61.0
# ISO 3166-2:WS
# EN.ATM.CO2E.PP.GD
# Samoa
# Polynesia
# WS
# WSM
# 678
# 3
# Middle Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 17.0
# ISO 3166-2:ST
# EN.ATM.CO2E.PP.GD
# Sao Tome and Principe
# Middle Africa
# ST
# STP
# 682
# 6
# Western Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 145.0
# ISO 3166-2:SA
# EN.ATM.CO2E.PP.GD
# Saudi Arabia
# Western Asia
# SA
# SAU
# 686
# 11
# Western Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 11.0
# ISO 3166-2:SN
# EN.ATM.CO2E.PP.GD
# Senegal
# Western Africa
# SN
# SEN
# 690
# 15
# Eastern Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 14.0
# ISO 3166-2:SC
# EN.ATM.CO2E.PP.GD
# Seychelles
# Eastern Africa
# SC
# SYC
# 694
# 11
# Western Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 11.0
# ISO 3166-2:SL
# EN.ATM.CO2E.PP.GD
# Sierra Leone
# Western Africa
# SL
# SLE
# 702
# 14
# South-Eastern Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 35.0
# ISO 3166-2:SG
# EN.ATM.CO2E.PP.GD
# Singapore
# South-Eastern Asia
# SG
# SGP
# 703
# 9
# Eastern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 151.0
# ISO 3166-2:SK
# EN.ATM.CO2E.PP.GD
# Slovak Republic
# Eastern Europe
# SK
# SVK
# 705
# 1
# Southern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 39.0
# ISO 3166-2:SI
# EN.ATM.CO2E.PP.GD
# Slovenia
# Southern Europe
# SI
# SVN
# 90
# 18
# Melanesia
# Oceania
# CO2 emissions (kg per PPP $ of GDP)
# 9.0
# 54.0
# ISO 3166-2:SB
# EN.ATM.CO2E.PP.GD
# Solomon Islands
# Melanesia
# SB
# SLB
# 710
# 13
# Southern Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 18.0
# ISO 3166-2:ZA
# EN.ATM.CO2E.PP.GD
# South Africa
# Southern Africa
# ZA
# ZAF
# 724
# 1
# Southern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 39.0
# ISO 3166-2:ES
# EN.ATM.CO2E.PP.GD
# Spain
# Southern Europe
# ES
# ESP
# 144
# 0
# Southern Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 34.0
# ISO 3166-2:LK
# EN.ATM.CO2E.PP.GD
# Sri Lanka
# Southern Asia
# LK
# LKA
# 659
# 4
# Caribbean
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 29.0
# ISO 3166-2:KN
# EN.ATM.CO2E.PP.GD
# St. Kitts and Nevis
# Caribbean
# KN
# KNA
# 662
# 4
# Caribbean
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 29.0
# ISO 3166-2:LC
# EN.ATM.CO2E.PP.GD
# St. Lucia
# Caribbean
# LC
# LCA
# 670
# 4
# Caribbean
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 29.0
# ISO 3166-2:VC
# EN.ATM.CO2E.PP.GD
# St. Vincent and the Grenadines
# Caribbean
# VC
# VCT
# 729
# 2
# Northern Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 15.0
# ISO 3166-2:SD
# EN.ATM.CO2E.PP.GD
# Sudan
# Northern Africa
# SD
# SDN
# 740
# 5
# South America
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 5.0
# ISO 3166-2:SR
# EN.ATM.CO2E.PP.GD
# Suriname
# South America
# SR
# SUR
# 748
# 13
# Southern Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 18.0
# ISO 3166-2:SZ
# EN.ATM.CO2E.PP.GD
# Swaziland
# Southern Africa
# SZ
# SWZ
# 752
# 17
# Northern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 154.0
# ISO 3166-2:SE
# EN.ATM.CO2E.PP.GD
# Sweden
# Northern Europe
# SE
# SWE
# 756
# 8
# Western Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 155.0
# ISO 3166-2:CH
# EN.ATM.CO2E.PP.GD
# Switzerland
# Western Europe
# CH
# CHE
# 762
# 19
# Central Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 143.0
# ISO 3166-2:TJ
# EN.ATM.CO2E.PP.GD
# Tajikistan
# Central Asia
# TJ
# TJK
# 834
# 15
# Eastern Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 14.0
# ISO 3166-2:TZ
# EN.ATM.CO2E.PP.GD
# Tanzania
# Eastern Africa
# TZ
# TZA
# 764
# 14
# South-Eastern Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 35.0
# ISO 3166-2:TH
# EN.ATM.CO2E.PP.GD
# Thailand
# South-Eastern Asia
# TH
# THA
# 626
# 14
# South-Eastern Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 35.0
# ISO 3166-2:TL
# EN.ATM.CO2E.PP.GD
# Timor-Leste
# South-Eastern Asia
# TL
# TLS
# 768
# 11
# Western Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 11.0
# ISO 3166-2:TG
# EN.ATM.CO2E.PP.GD
# Togo
# Western Africa
# TG
# TGO
# 776
# 21
# Polynesia
# Oceania
# CO2 emissions (kg per PPP $ of GDP)
# 9.0
# 61.0
# ISO 3166-2:TO
# EN.ATM.CO2E.PP.GD
# Tonga
# Polynesia
# TO
# TON
# 780
# 4
# Caribbean
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 29.0
# ISO 3166-2:TT
# EN.ATM.CO2E.PP.GD
# Trinidad and Tobago
# Caribbean
# TT
# TTO
# 788
# 2
# Northern Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 15.0
# ISO 3166-2:TN
# EN.ATM.CO2E.PP.GD
# Tunisia
# Northern Africa
# TN
# TUN
# 792
# 6
# Western Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 145.0
# ISO 3166-2:TR
# EN.ATM.CO2E.PP.GD
# Turkey
# Western Asia
# TR
# TUR
# 795
# 19
# Central Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 143.0
# ISO 3166-2:TM
# EN.ATM.CO2E.PP.GD
# Turkmenistan
# Central Asia
# TM
# TKM
# 798
# 21
# Polynesia
# Oceania
# CO2 emissions (kg per PPP $ of GDP)
# 9.0
# 61.0
# ISO 3166-2:TV
# EN.ATM.CO2E.PP.GD
# Tuvalu
# Polynesia
# TV
# TUV
# 800
# 15
# Eastern Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 14.0
# ISO 3166-2:UG
# EN.ATM.CO2E.PP.GD
# Uganda
# Eastern Africa
# UG
# UGA
# 804
# 9
# Eastern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 151.0
# ISO 3166-2:UA
# EN.ATM.CO2E.PP.GD
# Ukraine
# Eastern Europe
# UA
# UKR
# 784
# 6
# Western Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 145.0
# ISO 3166-2:AE
# EN.ATM.CO2E.PP.GD
# United Arab Emirates
# Western Asia
# AE
# ARE
# 826
# 17
# Northern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 154.0
# ISO 3166-2:GB
# EN.ATM.CO2E.PP.GD
# United Kingdom
# Northern Europe
# GB
# GBR
# 840
# 12
# Northern America
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 21.0
# ISO 3166-2:US
# EN.ATM.CO2E.PP.GD
# United States
# Northern America
# US
# USA
# 858
# 5
# South America
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 5.0
# ISO 3166-2:UY
# EN.ATM.CO2E.PP.GD
# Uruguay
# South America
# UY
# URY
# 860
# 19
# Central Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 143.0
# ISO 3166-2:UZ
# EN.ATM.CO2E.PP.GD
# Uzbekistan
# Central Asia
# UZ
# UZB
# 548
# 18
# Melanesia
# Oceania
# CO2 emissions (kg per PPP $ of GDP)
# 9.0
# 54.0
# ISO 3166-2:VU
# EN.ATM.CO2E.PP.GD
# Vanuatu
# Melanesia
# VU
# VUT
# 862
# 5
# South America
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 5.0
# ISO 3166-2:VE
# EN.ATM.CO2E.PP.GD
# Venezuela, RB
# South America
# VE
# VEN
# 704
# 14
# South-Eastern Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 35.0
# ISO 3166-2:VN
# EN.ATM.CO2E.PP.GD
# Vietnam
# South-Eastern Asia
# VN
# VNM
# 887
# 6
# Western Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 145.0
# ISO 3166-2:YE
# EN.ATM.CO2E.PP.GD
# Yemen, Rep.
# Western Asia
# YE
# YEM
# 894
# 15
# Eastern Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 14.0
# ISO 3166-2:ZM
# EN.ATM.CO2E.PP.GD
# Zambia
# Eastern Africa
# ZM
# ZMB
# 716
# 15
# Eastern Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 14.0
# ISO 3166-2:ZW
# EN.ATM.CO2E.PP.GD
# Zimbabwe
# Eastern Africa
# ZW
# ZWE
# <img src="data:image/png;base64,..." width="2500">
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-77-11d8f4b8d6a3> in <module>()
#      68 plot_graph(path_to_trajectories='./data/CO2_trajs.csv',
#      69            xaxis_title='test', yaxis_title ='ytest', title = 'hi',
# ---> 70            distinct_entry_tag='country_name')
#
# <ipython-input-77-11d8f4b8d6a3> in plot_graph(path_to_trajectories, xaxis_title, yaxis_title, title, distinct_entry_tag, xranges, yranges)
#      47
#      48     anim = animation.FuncAnimation(fig=fig, func=animate, fargs=[distinct_entry_tag, df, lines], frames=None, blit=True)
# ---> 49     HTML(anim.to_html5_video())
#      50 #     anim.save('graaaph.mp4', writer=writer)
#      51 def animate(i, distinct_entry_tag, df, lines):
#
# /Users/alexanderkyim/miniconda3/envs/tslvr/lib/python2.7/site-packages/matplotlib/animation.pyc in to_html5_video(self, embed_limit)
#    1351                                 bitrate=rcParams['animation.bitrate'],
#    1352                                 fps=1000. / self._interval)
# -> 1353                 self.save(f.name, writer=writer)
#    1354
#    1355             # Now open and base64 encode
#
# /Users/alexanderkyim/miniconda3/envs/tslvr/lib/python2.7/site-packages/matplotlib/animation.pyc in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs)
#    1193                 for anim in all_anim:
#    1194                     # Clear the initial frame
# -> 1195                     anim._init_draw()
#    1196                 for data in zip(*[a.new_saved_frame_seq() for a in all_anim]):
#    1197                     for anim, d in zip(all_anim, data):
#
# /Users/alexanderkyim/miniconda3/envs/tslvr/lib/python2.7/site-packages/matplotlib/animation.pyc in _init_draw(self)
#    1748         # artists.
#    1749         if self._init_func is None:
# -> 1750             self._draw_frame(next(self.new_frame_seq()))
#    1751
#    1752         else:
#
# /Users/alexanderkyim/miniconda3/envs/tslvr/lib/python2.7/site-packages/matplotlib/animation.pyc in _draw_frame(self, framedata)
#    1770         # Call the func with framedata and args. If blitting is desired,
#    1771         # func needs to return a sequence of any artists that were modified.
# -> 1772         self._drawn_artists = self._func(framedata, *self._args)
#    1773         if self._blit:
#    1774             if self._drawn_artists is None:
#
# <ipython-input-77-11d8f4b8d6a3> in animate(i, distinct_entry_tag, df, lines)
#      52     groo_DET = df.groupby(distinct_entry_tag)
#      53     for index, line in enumerate(groo.groups.keys()):
# ---> 54         lines[index].set_data(groo.get_group(line)['X'][i],groo.get_group(line)['Y'][i])
#      55     return lines
#      56
#
# IndexError: list index out of range

# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt
import random as rand
from matplotlib import animation, rc
from IPython.display import HTML

fig = plt.figure()
ax = plt.axes()
ax.set_xlim(( 0, 2))
ax.set_ylim((-8, 8))
plotcols = ['black', 'red','blue']
lines = [ax.plot([],[], lw=2, color = plotcols[index])[0] for _ in range(2)]

# line, = ax.plot([], [], lw=2)
# Out:
# <img src="data:image/png;base64,..." width="432">
# <img src="data:image/png;base64,..." width="432">

# %%
# initialization function: plot the background of each frame
def init():
    for line in lines:
        line.set_data([], [])
    return lines

# %%
# animation function. This is called sequentially
def animate(i):
    x = np.linspace(0, 2, 1000)
    y = np.sin(2 * np.pi * (x - 0.01 * i)) + rand.randint(0,4)
    for line in lines:
        line.set_data(x, y)
    return lines

# %%
# call the animator. blit=True means only re-draw the parts that have changed.
anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=1000, interval=20, blit=True)
plt.show()

# %%
    if xranges == [-0.313,0.313]:
        
    else:
        xlim = min(xranges),max(xranges)
    plt.xlabel(xaxis_title,fontsize=20)
    
    if yranges == [-0.313,0.313]:
        
    else:
        ylim = min(yranges),max(yranges)
    plt.ylabel(yaxis_title, fontsize=20)

# %%
df = utls.trajectories_to_dataframe(trajs=parse.read_trajectories('./data/CO2_trajs.csv'))
groo = df.groupby('country_name')
groo.get_group('Albania')['X'][0]
# Out:
# ...reading data
# 4
# 0
# Southern Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 34.0
# ISO 3166-2:AF
# EN.ATM.CO2E.PP.GD
# Afghanistan
# Southern Asia
# AF
# AFG
# 8
# 1
# Southern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 39.0
# ISO 3166-2:AL
# EN.ATM.CO2E.PP.GD
# Albania
# Southern Europe
# AL
# ALB
# 12
# 2
# Northern Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 15.0
# ISO 3166-2:DZ
# EN.ATM.CO2E.PP.GD
# Algeria
# Northern Africa
# DZ
# DZA
# 24
# 3
# Middle Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 17.0
# ISO 3166-2:AO
# EN.ATM.CO2E.PP.GD
# Angola
# Middle Africa
# AO
# AGO
# 28
# 4
# Caribbean
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 29.0
# ISO 3166-2:AG
# EN.ATM.CO2E.PP.GD
# Antigua and Barbuda
# Caribbean
# AG
# ATG
# 32
# 5
# South America
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 5.0
# ISO 3166-2:AR
# EN.ATM.CO2E.PP.GD
# Argentina
# South America
# AR
# ARG
# 51
# 6
# Western Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 145.0
# ISO 3166-2:AM
# EN.ATM.CO2E.PP.GD
# Armenia
# Western Asia
# AM
# ARM
# 36
# 7
# Australia and New Zealand
# Oceania
# CO2 emissions (kg per PPP $ of GDP)
# 9.0
# 53.0
# ISO 3166-2:AU
# EN.ATM.CO2E.PP.GD
# Australia
# Australia and New Zealand
# AU
# AUS
# 40
# 8
# Western Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 155.0
# ISO 3166-2:AT
# EN.ATM.CO2E.PP.GD
# Austria
# Western Europe
# AT
# AUT
# 31
# 6
# Western Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 145.0
# ISO 3166-2:AZ
# EN.ATM.CO2E.PP.GD
# Azerbaijan
# Western Asia
# AZ
# AZE
# 44
# 4
# Caribbean
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 29.0
# ISO 3166-2:BS
# EN.ATM.CO2E.PP.GD
# Bahamas, The
# Caribbean
# BS
# BHS
# 48
# 6
# Western Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 145.0
# ISO 3166-2:BH
# EN.ATM.CO2E.PP.GD
# Bahrain
# Western Asia
# BH
# BHR
# 50
# 0
# Southern Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 34.0
# ISO 3166-2:BD
# EN.ATM.CO2E.PP.GD
# Bangladesh
# Southern Asia
# BD
# BGD
# 52
# 4
# Caribbean
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 29.0
# ISO 3166-2:BB
# EN.ATM.CO2E.PP.GD
# Barbados
# Caribbean
# BB
# BRB
# 112
# 9
# Eastern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 151.0
# ISO 3166-2:BY
# EN.ATM.CO2E.PP.GD
# Belarus
# Eastern Europe
# BY
# BLR
# 56
# 8
# Western Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 155.0
# ISO 3166-2:BE
# EN.ATM.CO2E.PP.GD
# Belgium
# Western Europe
# BE
# BEL
# 84
# 10
# Central America
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 13.0
# ISO 3166-2:BZ
# EN.ATM.CO2E.PP.GD
# Belize
# Central America
# BZ
# BLZ
# 204
# 11
# Western Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 11.0
# ISO 3166-2:BJ
# EN.ATM.CO2E.PP.GD
# Benin
# Western Africa
# BJ
# BEN
# 60
# 12
# Northern America
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 21.0
# ISO 3166-2:BM
# EN.ATM.CO2E.PP.GD
# Bermuda
# Northern America
# BM
# BMU
# 64
# 0
# Southern Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 34.0
# ISO 3166-2:BT
# EN.ATM.CO2E.PP.GD
# Bhutan
# Southern Asia
# BT
# BTN
# 68
# 5
# South America
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 5.0
# ISO 3166-2:BO
# EN.ATM.CO2E.PP.GD
# Bolivia
# South America
# BO
# BOL
# 70
# 1
# Southern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 39.0
# ISO 3166-2:BA
# EN.ATM.CO2E.PP.GD
# Bosnia and Herzegovina
# Southern Europe
# BA
# BIH
# 72
# 13
# Southern Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 18.0
# ISO 3166-2:BW
# EN.ATM.CO2E.PP.GD
# Botswana
# Southern Africa
# BW
# BWA
# 76
# 5
# South America
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 5.0
# ISO 3166-2:BR
# EN.ATM.CO2E.PP.GD
# Brazil
# South America
# BR
# BRA
# 96
# 14
# South-Eastern Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 35.0
# ISO 3166-2:BN
# EN.ATM.CO2E.PP.GD
# Brunei Darussalam
# South-Eastern Asia
# BN
# BRN
# 100
# 9
# Eastern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 151.0
# ISO 3166-2:BG
# EN.ATM.CO2E.PP.GD
# Bulgaria
# Eastern Europe
# BG
# BGR
# 854
# 11
# Western Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 11.0
# ISO 3166-2:BF
# EN.ATM.CO2E.PP.GD
# Burkina Faso
# Western Africa
# BF
# BFA
# 108
# 15
# Eastern Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 14.0
# ISO 3166-2:BI
# EN.ATM.CO2E.PP.GD
# Burundi
# Eastern Africa
# BI
# BDI
# 132
# 11
# Western Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 11.0
# ISO 3166-2:CV
# EN.ATM.CO2E.PP.GD
# Cabo Verde
# Western Africa
# CV
# CPV
# 116
# 14
# South-Eastern Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 35.0
# ISO 3166-2:KH
# EN.ATM.CO2E.PP.GD
# Cambodia
# South-Eastern Asia
# KH
# KHM
# 120
# 3
# Middle Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 17.0
# ISO 3166-2:CM
# EN.ATM.CO2E.PP.GD
# Cameroon
# Middle Africa
# CM
# CMR
# 124
# 12
# Northern America
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 21.0
# ISO 3166-2:CA
# EN.ATM.CO2E.PP.GD
# Canada
# Northern America
# CA
# CAN
# 140
# 3
# Middle Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 17.0
# ISO 3166-2:CF
# EN.ATM.CO2E.PP.GD
# Central African Republic
# Middle Africa
# CF
# CAF
# 148
# 3
# Middle Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 17.0
# ISO 3166-2:TD
# EN.ATM.CO2E.PP.GD
# Chad
# Middle Africa
# TD
# TCD
# 152
# 5
# South America
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 5.0
# ISO 3166-2:CL
# EN.ATM.CO2E.PP.GD
# Chile
# South America
# CL
# CHL
# 156
# 16
# Eastern Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 30.0
# ISO 3166-2:CN
# EN.ATM.CO2E.PP.GD
# China
# Eastern Asia
# CN
# CHN
# 170
# 5
# South America
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 5.0
# ISO 3166-2:CO
# EN.ATM.CO2E.PP.GD
# Colombia
# South America
# CO
# COL
# 174
# 15
# Eastern Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 14.0
# ISO 3166-2:KM
# EN.ATM.CO2E.PP.GD
# Comoros
# Eastern Africa
# KM
# COM
# 180
# 3
# Middle Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 17.0
# ISO 3166-2:CD
# EN.ATM.CO2E.PP.GD
# Congo, Dem. Rep.
# Middle Africa
# CD
# COD
# 178
# 3
# Middle Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 17.0
# ISO 3166-2:CG
# EN.ATM.CO2E.PP.GD
# Congo, Rep.
# Middle Africa
# CG
# COG
# 188
# 10
# Central America
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 13.0
# ISO 3166-2:CR
# EN.ATM.CO2E.PP.GD
# Costa Rica
# Central America
# CR
# CRI
# 384
# 11
# Western Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 11.0
# ISO 3166-2:CI
# EN.ATM.CO2E.PP.GD
# Cote d'Ivoire
# Western Africa
# CI
# CIV
# 191
# 1
# Southern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 39.0
# ISO 3166-2:HR
# EN.ATM.CO2E.PP.GD
# Croatia
# Southern Europe
# HR
# HRV
# 196
# 6
# Western Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 145.0
# ISO 3166-2:CY
# EN.ATM.CO2E.PP.GD
# Cyprus
# Western Asia
# CY
# CYP
# 203
# 9
# Eastern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 151.0
# ISO 3166-2:CZ
# EN.ATM.CO2E.PP.GD
# Czech Republic
# Eastern Europe
# CZ
# CZE
# 208
# 17
# Northern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 154.0
# ISO 3166-2:DK
# EN.ATM.CO2E.PP.GD
# Denmark
# Northern Europe
# DK
# DNK
# 262
# 15
# Eastern Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 14.0
# ISO 3166-2:DJ
# EN.ATM.CO2E.PP.GD
# Djibouti
# Eastern Africa
# DJ
# DJI
# 212
# 4
# Caribbean
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 29.0
# ISO 3166-2:DM
# EN.ATM.CO2E.PP.GD
# Dominica
# Caribbean
# DM
# DMA
# 214
# 4
# Caribbean
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 29.0
# ISO 3166-2:DO
# EN.ATM.CO2E.PP.GD
# Dominican Republic
# Caribbean
# DO
# DOM
# 218
# 5
# South America
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 5.0
# ISO 3166-2:EC
# EN.ATM.CO2E.PP.GD
# Ecuador
# South America
# EC
# ECU
# 818
# 2
# Northern Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 15.0
# ISO 3166-2:EG
# EN.ATM.CO2E.PP.GD
# Egypt, Arab Rep.
# Northern Africa
# EG
# EGY
# 222
# 10
# Central America
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 13.0
# ISO 3166-2:SV
# EN.ATM.CO2E.PP.GD
# El Salvador
# Central America
# SV
# SLV
# 226
# 3
# Middle Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 17.0
# ISO 3166-2:GQ
# EN.ATM.CO2E.PP.GD
# Equatorial Guinea
# Middle Africa
# GQ
# GNQ
# 232
# 15
# Eastern Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 14.0
# ISO 3166-2:ER
# EN.ATM.CO2E.PP.GD
# Eritrea
# Eastern Africa
# ER
# ERI
# 233
# 17
# Northern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 154.0
# ISO 3166-2:EE
# EN.ATM.CO2E.PP.GD
# Estonia
# Northern Europe
# EE
# EST
# 231
# 15
# Eastern Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 14.0
# ISO 3166-2:ET
# EN.ATM.CO2E.PP.GD
# Ethiopia
# Eastern Africa
# ET
# ETH
# 242
# 18
# Melanesia
# Oceania
# CO2 emissions (kg per PPP $ of GDP)
# 9.0
# 54.0
# ISO 3166-2:FJ
# EN.ATM.CO2E.PP.GD
# Fiji
# Melanesia
# FJ
# FJI
# 246
# 17
# Northern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 154.0
# ISO 3166-2:FI
# EN.ATM.CO2E.PP.GD
# Finland
# Northern Europe
# FI
# FIN
# 250
# 8
# Western Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 155.0
# ISO 3166-2:FR
# EN.ATM.CO2E.PP.GD
# France
# Western Europe
# FR
# FRA
# 266
# 3
# Middle Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 17.0
# ISO 3166-2:GA
# EN.ATM.CO2E.PP.GD
# Gabon
# Middle Africa
# GA
# GAB
# 270
# 11
# Western Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 11.0
# ISO 3166-2:GM
# EN.ATM.CO2E.PP.GD
# Gambia, The
# Western Africa
# GM
# GMB
# 268
# 6
# Western Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 145.0
# ISO 3166-2:GE
# EN.ATM.CO2E.PP.GD
# Georgia
# Western Asia
# GE
# GEO
# 276
# 8
# Western Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 155.0
# ISO 3166-2:DE
# EN.ATM.CO2E.PP.GD
# Germany
# Western Europe
# DE
# DEU
# 288
# 11
# Western Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 11.0
# ISO 3166-2:GH
# EN.ATM.CO2E.PP.GD
# Ghana
# Western Africa
# GH
# GHA
# 300
# 1
# Southern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 39.0
# ISO 3166-2:GR
# EN.ATM.CO2E.PP.GD
# Greece
# Southern Europe
# GR
# GRC
# 308
# 4
# Caribbean
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 29.0
# ISO 3166-2:GD
# EN.ATM.CO2E.PP.GD
# Grenada
# Caribbean
# GD
# GRD
# 320
# 10
# Central America
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 13.0
# ISO 3166-2:GT
# EN.ATM.CO2E.PP.GD
# Guatemala
# Central America
# GT
# GTM
# 324
# 11
# Western Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 11.0
# ISO 3166-2:GN
# EN.ATM.CO2E.PP.GD
# Guinea
# Western Africa
# GN
# GIN
# 624
# 11
# Western Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 11.0
# ISO 3166-2:GW
# EN.ATM.CO2E.PP.GD
# Guinea-Bissau
# Western Africa
# GW
# GNB
# 328
# 5
# South America
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 5.0
# ISO 3166-2:GY
# EN.ATM.CO2E.PP.GD
# Guyana
# South America
# GY
# GUY
# 332
# 4
# Caribbean
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 29.0
# ISO 3166-2:HT
# EN.ATM.CO2E.PP.GD
# Haiti
# Caribbean
# HT
# HTI
# 340
# 10
# Central America
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 13.0
# ISO 3166-2:HN
# EN.ATM.CO2E.PP.GD
# Honduras
# Central America
# HN
# HND
# 344
# 16
# Eastern Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 30.0
# ISO 3166-2:HK
# EN.ATM.CO2E.PP.GD
# Hong Kong SAR, China
# Eastern Asia
# HK
# HKG
# 348
# 9
# Eastern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 151.0
# ISO 3166-2:HU
# EN.ATM.CO2E.PP.GD
# Hungary
# Eastern Europe
# HU
# HUN
# 352
# 17
# Northern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 154.0
# ISO 3166-2:IS
# EN.ATM.CO2E.PP.GD
# Iceland
# Northern Europe
# IS
# ISL
# 356
# 0
# Southern Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 34.0
# ISO 3166-2:IN
# EN.ATM.CO2E.PP.GD
# India
# Southern Asia
# IN
# IND
# 360
# 14
# South-Eastern Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 35.0
# ISO 3166-2:ID
# EN.ATM.CO2E.PP.GD
# Indonesia
# South-Eastern Asia
# ID
# IDN
# 364
# 0
# Southern Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 34.0
# ISO 3166-2:IR
# EN.ATM.CO2E.PP.GD
# Iran, Islamic Rep.
# Southern Asia
# IR
# IRN
# 368
# 6
# Western Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 145.0
# ISO 3166-2:IQ
# EN.ATM.CO2E.PP.GD
# Iraq
# Western Asia
# IQ
# IRQ
# 372
# 17
# Northern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 154.0
# ISO 3166-2:IE
# EN.ATM.CO2E.PP.GD
# Ireland
# Northern Europe
# IE
# IRL
# 376
# 6
# Western Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 145.0
# ISO 3166-2:IL
# EN.ATM.CO2E.PP.GD
# Israel
# Western Asia
# IL
# ISR
# 380
# 1
# Southern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 39.0
# ISO 3166-2:IT
# EN.ATM.CO2E.PP.GD
# Italy
# Southern Europe
# IT
# ITA
# 388
# 4
# Caribbean
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 29.0
# ISO 3166-2:JM
# EN.ATM.CO2E.PP.GD
# Jamaica
# Caribbean
# JM
# JAM
# 392
# 16
# Eastern Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 30.0
# ISO 3166-2:JP
# EN.ATM.CO2E.PP.GD
# Japan
# Eastern Asia
# JP
# JPN
# 400
# 6
# Western Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 145.0
# ISO 3166-2:JO
# EN.ATM.CO2E.PP.GD
# Jordan
# Western Asia
# JO
# JOR
# 398
# 19
# Central Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 143.0
# ISO 3166-2:KZ
# EN.ATM.CO2E.PP.GD
# Kazakhstan
# Central Asia
# KZ
# KAZ
# 404
# 15
# Eastern Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 14.0
# ISO 3166-2:KE
# EN.ATM.CO2E.PP.GD
# Kenya
# Eastern Africa
# KE
# KEN
# 296
# 20
# Micronesia
# Oceania
# CO2 emissions (kg per PPP $ of GDP)
# 9.0
# 57.0
# ISO 3166-2:KI
# EN.ATM.CO2E.PP.GD
# Kiribati
# Micronesia
# KI
# KIR
# 410
# 16
# Eastern Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 30.0
# ISO 3166-2:KR
# EN.ATM.CO2E.PP.GD
# Korea, Rep.
# Eastern Asia
# KR
# KOR
# 414
# 6
# Western Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 145.0
# ISO 3166-2:KW
# EN.ATM.CO2E.PP.GD
# Kuwait
# Western Asia
# KW
# KWT
# 417
# 19
# Central Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 143.0
# ISO 3166-2:KG
# EN.ATM.CO2E.PP.GD
# Kyrgyz Republic
# Central Asia
# KG
# KGZ
# 418
# 14
# South-Eastern Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 35.0
# ISO 3166-2:LA
# EN.ATM.CO2E.PP.GD
# Lao PDR
# South-Eastern Asia
# LA
# LAO
# 428
# 17
# Northern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 154.0
# ISO 3166-2:LV
# EN.ATM.CO2E.PP.GD
# Latvia
# Northern Europe
# LV
# LVA
# 422
# 6
# Western Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 145.0
# ISO 3166-2:LB
# EN.ATM.CO2E.PP.GD
# Lebanon
# Western Asia
# LB
# LBN
# 426
# 13
# Southern Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 18.0
# ISO 3166-2:LS
# EN.ATM.CO2E.PP.GD
# Lesotho
# Southern Africa
# LS
# LSO
# 430
# 11
# Western Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 11.0
# ISO 3166-2:LR
# EN.ATM.CO2E.PP.GD
# Liberia
# Western Africa
# LR
# LBR
# 434
# 2
# Northern Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 15.0
# ISO 3166-2:LY
# EN.ATM.CO2E.PP.GD
# Libya
# Northern Africa
# LY
# LBY
# 440
# 17
# Northern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 154.0
# ISO 3166-2:LT
# EN.ATM.CO2E.PP.GD
# Lithuania
# Northern Europe
# LT
# LTU
# 442
# 8
# Western Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 155.0
# ISO 3166-2:LU
# EN.ATM.CO2E.PP.GD
# Luxembourg
# Western Europe
# LU
# LUX
# 446
# 16
# Eastern Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 30.0
# ISO 3166-2:MO
# EN.ATM.CO2E.PP.GD
# Macao SAR, China
# Eastern Asia
# MO
# MAC
# 807
# 1
# Southern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 39.0
# ISO 3166-2:MK
# EN.ATM.CO2E.PP.GD
# Macedonia, FYR
# Southern Europe
# MK
# MKD
# 450
# 15
# Eastern Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 14.0
# ISO 3166-2:MG
# EN.ATM.CO2E.PP.GD
# Madagascar
# Eastern Africa
# MG
# MDG
# 454
# 15
# Eastern Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 14.0
# ISO 3166-2:MW
# EN.ATM.CO2E.PP.GD
# Malawi
# Eastern Africa
# MW
# MWI
# 458
# 14
# South-Eastern Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 35.0
# ISO 3166-2:MY
# EN.ATM.CO2E.PP.GD
# Malaysia
# South-Eastern Asia
# MY
# MYS
# 462
# 0
# Southern Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 34.0
# ISO 3166-2:MV
# EN.ATM.CO2E.PP.GD
# Maldives
# Southern Asia
# MV
# MDV
# 466
# 11
# Western Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 11.0
# ISO 3166-2:ML
# EN.ATM.CO2E.PP.GD
# Mali
# Western Africa
# ML
# MLI
# 470
# 1
# Southern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 39.0
# ISO 3166-2:MT
# EN.ATM.CO2E.PP.GD
# Malta
# Southern Europe
# MT
# MLT
# 584
# 20
# Micronesia
# Oceania
# CO2 emissions (kg per PPP $ of GDP)
# 9.0
# 57.0
# ISO 3166-2:MH
# EN.ATM.CO2E.PP.GD
# Marshall Islands
# Micronesia
# MH
# MHL
# 478
# 11
# Western Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 11.0
# ISO 3166-2:MR
# EN.ATM.CO2E.PP.GD
# Mauritania
# Western Africa
# MR
# MRT
# 480
# 15
# Eastern Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 14.0
# ISO 3166-2:MU
# EN.ATM.CO2E.PP.GD
# Mauritius
# Eastern Africa
# MU
# MUS
# 484
# 10
# Central America
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 13.0
# ISO 3166-2:MX
# EN.ATM.CO2E.PP.GD
# Mexico
# Central America
# MX
# MEX
# 583
# 20
# Micronesia
# Oceania
# CO2 emissions (kg per PPP $ of GDP)
# 9.0
# 57.0
# ISO 3166-2:FM
# EN.ATM.CO2E.PP.GD
# Micronesia, Fed. Sts.
# Micronesia
# FM
# FSM
# 498
# 9
# Eastern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 151.0
# ISO 3166-2:MD
# EN.ATM.CO2E.PP.GD
# Moldova
# Eastern Europe
# MD
# MDA
# 496
# 16
# Eastern Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 30.0
# ISO 3166-2:MN
# EN.ATM.CO2E.PP.GD
# Mongolia
# Eastern Asia
# MN
# MNG
# 499
# 1
# Southern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 39.0
# ISO 3166-2:ME
# EN.ATM.CO2E.PP.GD
# Montenegro
# Southern Europe
# ME
# MNE
# 504
# 2
# Northern Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 15.0
# ISO 3166-2:MA
# EN.ATM.CO2E.PP.GD
# Morocco
# Northern Africa
# MA
# MAR
# 508
# 15
# Eastern Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 14.0
# ISO 3166-2:MZ
# EN.ATM.CO2E.PP.GD
# Mozambique
# Eastern Africa
# MZ
# MOZ
# 104
# 14
# South-Eastern Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 35.0
# ISO 3166-2:MM
# EN.ATM.CO2E.PP.GD
# Myanmar
# South-Eastern Asia
# MM
# MMR
# 516
# 13
# Southern Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 18.0
# ISO 3166-2:NA
# EN.ATM.CO2E.PP.GD
# Namibia
# Southern Africa
# nan
# NAM
# 524
# 0
# Southern Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 34.0
# ISO 3166-2:NP
# EN.ATM.CO2E.PP.GD
# Nepal
# Southern Asia
# NP
# NPL
# 528
# 8
# Western Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 155.0
# ISO 3166-2:NL
# EN.ATM.CO2E.PP.GD
# Netherlands
# Western Europe
# NL
# NLD
# 554
# 7
# Australia and New Zealand
# Oceania
# CO2 emissions (kg per PPP $ of GDP)
# 9.0
# 53.0
# ISO 3166-2:NZ
# EN.ATM.CO2E.PP.GD
# New Zealand
# Australia and New Zealand
# NZ
# NZL
# 558
# 10
# Central America
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 13.0
# ISO 3166-2:NI
# EN.ATM.CO2E.PP.GD
# Nicaragua
# Central America
# NI
# NIC
# 562
# 11
# Western Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 11.0
# ISO 3166-2:NE
# EN.ATM.CO2E.PP.GD
# Niger
# Western Africa
# NE
# NER
# 566
# 11
# Western Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 11.0
# ISO 3166-2:NG
# EN.ATM.CO2E.PP.GD
# Nigeria
# Western Africa
# NG
# NGA
# 578
# 17
# Northern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 154.0
# ISO 3166-2:NO
# EN.ATM.CO2E.PP.GD
# Norway
# Northern Europe
# NO
# NOR
# 512
# 6
# Western Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 145.0
# ISO 3166-2:OM
# EN.ATM.CO2E.PP.GD
# Oman
# Western Asia
# OM
# OMN
# 586
# 0
# Southern Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 34.0
# ISO 3166-2:PK
# EN.ATM.CO2E.PP.GD
# Pakistan
# Southern Asia
# PK
# PAK
# 585
# 20
# Micronesia
# Oceania
# CO2 emissions (kg per PPP $ of GDP)
# 9.0
# 57.0
# ISO 3166-2:PW
# EN.ATM.CO2E.PP.GD
# Palau
# Micronesia
# PW
# PLW
# 591
# 10
# Central America
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 13.0
# ISO 3166-2:PA
# EN.ATM.CO2E.PP.GD
# Panama
# Central America
# PA
# PAN
# 598
# 18
# Melanesia
# Oceania
# CO2 emissions (kg per PPP $ of GDP)
# 9.0
# 54.0
# ISO 3166-2:PG
# EN.ATM.CO2E.PP.GD
# Papua New Guinea
# Melanesia
# PG
# PNG
# 600
# 5
# South America
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 5.0
# ISO 3166-2:PY
# EN.ATM.CO2E.PP.GD
# Paraguay
# South America
# PY
# PRY
# 604
# 5
# South America
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 5.0
# ISO 3166-2:PE
# EN.ATM.CO2E.PP.GD
# Peru
# South America
# PE
# PER
# 608
# 14
# South-Eastern Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 35.0
# ISO 3166-2:PH
# EN.ATM.CO2E.PP.GD
# Philippines
# South-Eastern Asia
# PH
# PHL
# 616
# 9
# Eastern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 151.0
# ISO 3166-2:PL
# EN.ATM.CO2E.PP.GD
# Poland
# Eastern Europe
# PL
# POL
# 620
# 1
# Southern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 39.0
# ISO 3166-2:PT
# EN.ATM.CO2E.PP.GD
# Portugal
# Southern Europe
# PT
# PRT
# 634
# 6
# Western Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 145.0
# ISO 3166-2:QA
# EN.ATM.CO2E.PP.GD
# Qatar
# Western Asia
# QA
# QAT
# 642
# 9
# Eastern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 151.0
# ISO 3166-2:RO
# EN.ATM.CO2E.PP.GD
# Romania
# Eastern Europe
# RO
# ROU
# 643
# 9
# Eastern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 151.0
# ISO 3166-2:RU
# EN.ATM.CO2E.PP.GD
# Russian Federation
# Eastern Europe
# RU
# RUS
# 646
# 15
# Eastern Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 14.0
# ISO 3166-2:RW
# EN.ATM.CO2E.PP.GD
# Rwanda
# Eastern Africa
# RW
# RWA
# 882
# 21
# Polynesia
# Oceania
# CO2 emissions (kg per PPP $ of GDP)
# 9.0
# 61.0
# ISO 3166-2:WS
# EN.ATM.CO2E.PP.GD
# Samoa
# Polynesia
# WS
# WSM
# 678
# 3
# Middle Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 17.0
# ISO 3166-2:ST
# EN.ATM.CO2E.PP.GD
# Sao Tome and Principe
# Middle Africa
# ST
# STP
# 682
# 6
# Western Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 145.0
# ISO 3166-2:SA
# EN.ATM.CO2E.PP.GD
# Saudi Arabia
# Western Asia
# SA
# SAU
# 686
# 11
# Western Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 11.0
# ISO 3166-2:SN
# EN.ATM.CO2E.PP.GD
# Senegal
# Western Africa
# SN
# SEN
# 690
# 15
# Eastern Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 14.0
# ISO 3166-2:SC
# EN.ATM.CO2E.PP.GD
# Seychelles
# Eastern Africa
# SC
# SYC
# 694
# 11
# Western Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 11.0
# ISO 3166-2:SL
# EN.ATM.CO2E.PP.GD
# Sierra Leone
# Western Africa
# SL
# SLE
# 702
# 14
# South-Eastern Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 35.0
# ISO 3166-2:SG
# EN.ATM.CO2E.PP.GD
# Singapore
# South-Eastern Asia
# SG
# SGP
# 703
# 9
# Eastern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 151.0
# ISO 3166-2:SK
# EN.ATM.CO2E.PP.GD
# Slovak Republic
# Eastern Europe
# SK
# SVK
# 705
# 1
# Southern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 39.0
# ISO 3166-2:SI
# EN.ATM.CO2E.PP.GD
# Slovenia
# Southern Europe
# SI
# SVN
# 90
# 18
# Melanesia
# Oceania
# CO2 emissions (kg per PPP $ of GDP)
# 9.0
# 54.0
# ISO 3166-2:SB
# EN.ATM.CO2E.PP.GD
# Solomon Islands
# Melanesia
# SB
# SLB
# 710
# 13
# Southern Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 18.0
# ISO 3166-2:ZA
# EN.ATM.CO2E.PP.GD
# South Africa
# Southern Africa
# ZA
# ZAF
# 724
# 1
# Southern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 39.0
# ISO 3166-2:ES
# EN.ATM.CO2E.PP.GD
# Spain
# Southern Europe
# ES
# ESP
# 144
# 0
# Southern Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 34.0
# ISO 3166-2:LK
# EN.ATM.CO2E.PP.GD
# Sri Lanka
# Southern Asia
# LK
# LKA
# 659
# 4
# Caribbean
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 29.0
# ISO 3166-2:KN
# EN.ATM.CO2E.PP.GD
# St. Kitts and Nevis
# Caribbean
# KN
# KNA
# 662
# 4
# Caribbean
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 29.0
# ISO 3166-2:LC
# EN.ATM.CO2E.PP.GD
# St. Lucia
# Caribbean
# LC
# LCA
# 670
# 4
# Caribbean
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 29.0
# ISO 3166-2:VC
# EN.ATM.CO2E.PP.GD
# St. Vincent and the Grenadines
# Caribbean
# VC
# VCT
# 729
# 2
# Northern Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 15.0
# ISO 3166-2:SD
# EN.ATM.CO2E.PP.GD
# Sudan
# Northern Africa
# SD
# SDN
# 740
# 5
# South America
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 5.0
# ISO 3166-2:SR
# EN.ATM.CO2E.PP.GD
# Suriname
# South America
# SR
# SUR
# 748
# 13
# Southern Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 18.0
# ISO 3166-2:SZ
# EN.ATM.CO2E.PP.GD
# Swaziland
# Southern Africa
# SZ
# SWZ
# 752
# 17
# Northern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 154.0
# ISO 3166-2:SE
# EN.ATM.CO2E.PP.GD
# Sweden
# Northern Europe
# SE
# SWE
# 756
# 8
# Western Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 155.0
# ISO 3166-2:CH
# EN.ATM.CO2E.PP.GD
# Switzerland
# Western Europe
# CH
# CHE
# 762
# 19
# Central Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 143.0
# ISO 3166-2:TJ
# EN.ATM.CO2E.PP.GD
# Tajikistan
# Central Asia
# TJ
# TJK
# 834
# 15
# Eastern Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 14.0
# ISO 3166-2:TZ
# EN.ATM.CO2E.PP.GD
# Tanzania
# Eastern Africa
# TZ
# TZA
# 764
# 14
# South-Eastern Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 35.0
# ISO 3166-2:TH
# EN.ATM.CO2E.PP.GD
# Thailand
# South-Eastern Asia
# TH
# THA
# 626
# 14
# South-Eastern Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 35.0
# ISO 3166-2:TL
# EN.ATM.CO2E.PP.GD
# Timor-Leste
# South-Eastern Asia
# TL
# TLS
# 768
# 11
# Western Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 11.0
# ISO 3166-2:TG
# EN.ATM.CO2E.PP.GD
# Togo
# Western Africa
# TG
# TGO
# 776
# 21
# Polynesia
# Oceania
# CO2 emissions (kg per PPP $ of GDP)
# 9.0
# 61.0
# ISO 3166-2:TO
# EN.ATM.CO2E.PP.GD
# Tonga
# Polynesia
# TO
# TON
# 780
# 4
# Caribbean
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 29.0
# ISO 3166-2:TT
# EN.ATM.CO2E.PP.GD
# Trinidad and Tobago
# Caribbean
# TT
# TTO
# 788
# 2
# Northern Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 15.0
# ISO 3166-2:TN
# EN.ATM.CO2E.PP.GD
# Tunisia
# Northern Africa
# TN
# TUN
# 792
# 6
# Western Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 145.0
# ISO 3166-2:TR
# EN.ATM.CO2E.PP.GD
# Turkey
# Western Asia
# TR
# TUR
# 795
# 19
# Central Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 143.0
# ISO 3166-2:TM
# EN.ATM.CO2E.PP.GD
# Turkmenistan
# Central Asia
# TM
# TKM
# 798
# 21
# Polynesia
# Oceania
# CO2 emissions (kg per PPP $ of GDP)
# 9.0
# 61.0
# ISO 3166-2:TV
# EN.ATM.CO2E.PP.GD
# Tuvalu
# Polynesia
# TV
# TUV
# 800
# 15
# Eastern Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 14.0
# ISO 3166-2:UG
# EN.ATM.CO2E.PP.GD
# Uganda
# Eastern Africa
# UG
# UGA
# 804
# 9
# Eastern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 151.0
# ISO 3166-2:UA
# EN.ATM.CO2E.PP.GD
# Ukraine
# Eastern Europe
# UA
# UKR
# 784
# 6
# Western Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 145.0
# ISO 3166-2:AE
# EN.ATM.CO2E.PP.GD
# United Arab Emirates
# Western Asia
# AE
# ARE
# 826
# 17
# Northern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 154.0
# ISO 3166-2:GB
# EN.ATM.CO2E.PP.GD
# United Kingdom
# Northern Europe
# GB
# GBR
# 840
# 12
# Northern America
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 21.0
# ISO 3166-2:US
# EN.ATM.CO2E.PP.GD
# United States
# Northern America
# US
# USA
# 858
# 5
# South America
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 5.0
# ISO 3166-2:UY
# EN.ATM.CO2E.PP.GD
# Uruguay
# South America
# UY
# URY
# 860
# 19
# Central Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 143.0
# ISO 3166-2:UZ
# EN.ATM.CO2E.PP.GD
# Uzbekistan
# Central Asia
# UZ
# UZB
# 548
# 18
# Melanesia
# Oceania
# CO2 emissions (kg per PPP $ of GDP)
# 9.0
# 54.0
# ISO 3166-2:VU
# EN.ATM.CO2E.PP.GD
# Vanuatu
# Melanesia
# VU
# VUT
# 862
# 5
# South America
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 5.0
# ISO 3166-2:VE
# EN.ATM.CO2E.PP.GD
# Venezuela, RB
# South America
# VE
# VEN
# 704
# 14
# South-Eastern Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 35.0
# ISO 3166-2:VN
# EN.ATM.CO2E.PP.GD
# Vietnam
# South-Eastern Asia
# VN
# VNM
# 887
# 6
# Western Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 145.0
# ISO 3166-2:YE
# EN.ATM.CO2E.PP.GD
# Yemen, Rep.
# Western Asia
# YE
# YEM
# 894
# 15
# Eastern Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 14.0
# ISO 3166-2:ZM
# EN.ATM.CO2E.PP.GD
# Zambia
# Eastern Africa
# ZM
# ZMB
# 716
# 15
# Eastern Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 14.0
# ISO 3166-2:ZW
# EN.ATM.CO2E.PP.GD
# Zimbabwe
# Eastern Africa
# ZW
# ZWE
# 1990.0

# %%
import matplotlib.animation as animation
help(animation.FuncAnimation)
# Out:
# Help on class FuncAnimation in module matplotlib.animation:
#
# class FuncAnimation(TimedAnimation)
#  |  Makes an animation by repeatedly calling a function ``func``.
#  |
#  |  Parameters
#  |  ----------
#  |  fig : matplotlib.figure.Figure
#  |     The figure object that is used to get draw, resize, and any
#  |     other needed events.
#  |
#  |  func : callable
#  |     The function to call at each frame.  The first argument will
#  |     be the next value in ``frames``.   Any additional positional
#  |     arguments can be supplied via the ``fargs`` parameter.
#  |
#  |     The required signature is::
#  |
#  |        def func(frame, *fargs) -> iterable_of_artists:
#  |
#  |  frames : iterable, int, generator function, or None, optional
#  |      Source of data to pass ``func`` and each frame of the animation
#  |
#  |      If an iterable, then simply use the values provided.  If the
#  |      iterable has a length, it will override the ``save_count`` kwarg.
#  |
#  |      If an integer, then equivalent to passing ``range(frames)``
#  |
#  |      If a generator function, then must have the signature::
#  |
#  |         def gen_function() -> obj:
#  |
#  |      If ``None``, then equivalent to passing ``itertools.count``.
#  |
#  |      In all of these cases, the values in *frames* is simply passed through
#  |      to the user-supplied *func* and thus can be of any type.
#  |
#  |  init_func : callable, optional
#  |     A function used to draw a clear frame. If not given, the
#  |     results of drawing from the first item in the frames sequence
#  |     will be used. This function will be called once before the
#  |     first frame.
#  |
#  |     If ``blit == True``, ``init_func`` must return an iterable of artists
#  |     to be re-drawn.
#  |
#  |     The required signature is::
#  |
#  |        def init_func() -> iterable_of_artists:
#  |
#  |  fargs : tuple or None, optional
#  |     Additional arguments to pass to each call to *func*.
#  |
#  |  save_count : int, optional
#  |     The number of values from *frames* to cache.
#  |
#  |  interval : number, optional
#  |     Delay between frames in milliseconds.  Defaults to 200.
#  |
#  |  repeat_delay : number, optional
#  |     If the animation in repeated, adds a delay in milliseconds
#  |     before repeating the animation.  Defaults to ``None``.
#  |
#  |  repeat : bool, optional
#  |     Controls whether the animation should repeat when the sequence
#  |     of frames is completed.  Defaults to ``True``.
#  |
#  |  blit : bool, optional
#  |     Controls whether blitting is used to optimize drawing.  Defaults
#  |     to ``False``.
#  |
#  |  Method resolution order:
#  |      FuncAnimation
#  |      TimedAnimation
#  |      Animation
#  |      __builtin__.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, fig, func, frames=None, init_func=None, fargs=None, save_count=None, **kwargs)
#  |
#  |  new_frame_seq(self)
#  |
#  |  new_saved_frame_seq(self)
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from Animation:
#  |
#  |  save(self, filename, writer=None, fps=None, dpi=None, codec=None, bitrate=None, extra_args=None, metadata=None, extra_anim=None, savefig_kwargs=None)
#  |      Saves a movie file by drawing every frame.
#  |
#  |      Parameters
#  |      ----------
#  |
#  |      filename : str
#  |          The output filename, e.g., :file:`mymovie.mp4`.
#  |
#  |      writer : :class:`MovieWriter` or str, optional
#  |          A `MovieWriter` instance to use or a key that identifies a
#  |          class to use, such as 'ffmpeg'. If ``None``, defaults to
#  |          :rc:`animation.writer`.
#  |
#  |      fps : number, optional
#  |         Frames per second in the movie. Defaults to ``None``, which will use
#  |         the animation's specified interval to set the frames per second.
#  |
#  |      dpi : number, optional
#  |         Controls the dots per inch for the movie frames.  This combined with
#  |         the figure's size in inches controls the size of the movie.  If
#  |         ``None``, defaults to :rc:`savefig.dpi`.
#  |
#  |      codec : str, optional
#  |         The video codec to be used. Not all codecs are supported
#  |         by a given :class:`MovieWriter`. If ``None``, default to
#  |         :rc:`animation.codec`.
#  |
#  |      bitrate : number, optional
#  |         Specifies the number of bits used per second in the compressed
#  |         movie, in kilobits per second. A higher number means a higher
#  |         quality movie, but at the cost of increased file size. If ``None``,
#  |         defaults to :rc:`animation.bitrate`.
#  |
#  |      extra_args : list, optional
#  |         List of extra string arguments to be passed to the underlying movie
#  |         utility. If ``None``, defaults to :rc:`animation.extra_args`.
#  |
#  |      metadata : Dict[str, str], optional
#  |         Dictionary of keys and values for metadata to include in
#  |         the output file. Some keys that may be of use include:
#  |         title, artist, genre, subject, copyright, srcform, comment.
#  |
#  |      extra_anim : list, optional
#  |         Additional `Animation` objects that should be included
#  |         in the saved movie file. These need to be from the same
#  |         `matplotlib.figure.Figure` instance. Also, animation frames will
#  |         just be simply combined, so there should be a 1:1 correspondence
#  |         between the frames from the different animations.
#  |
#  |      savefig_kwargs : dict, optional
#  |         Is a dictionary containing keyword arguments to be passed
#  |         on to the `savefig` command which is called repeatedly to
#  |         save the individual frames.
#  |
#  |      Notes
#  |      -----
#  |      fps, codec, bitrate, extra_args, metadata are used to
#  |      construct a :class:`MovieWriter` instance and can only be
#  |      passed if `writer` is a string.  If they are passed as
#  |      non-`None` and ``writer`` is a :class:`MovieWriter`, a
#  |      `RuntimeError` will be raised.
#  |
#  |  to_html5_video(self, embed_limit=None)
#  |      Returns animation as an HTML5 video tag.
#  |
#  |      This saves the animation as an h264 video, encoded in base64
#  |      directly into the HTML5 video tag. This respects the rc parameters
#  |      for the writer as well as the bitrate. This also makes use of the
#  |      ``interval`` to control the speed, and uses the ``repeat``
#  |      parameter to decide whether to loop.
#  |
#  |  to_jshtml(self, fps=None, embed_frames=True, default_mode=None)
#  |      Generate HTML representation of the animation
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from Animation:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
def plot_graph(path_to_trajectories, xaxis_title, 
               yaxis_title, title, distinct_entry_tag, 
               xranges=[-0.313,0.313], yranges = [-0.313,0.313]):
# Out:
# 4

# %%
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import pandas as pd
import numpy as np

N=11

dataframes = [pd.DataFrame({"x":np.sort(np.random.rand(10)*100),
                            "y1":np.random.rand(10)*30,
                            "y2":np.random.rand(10)*30}) for _ in range(N)]

fig = plt.figure()
ax = plt.axes(xlim=(0,100), ylim=(0,30))

lines = [plt.plot([], [])[0] for _ in range(2)]

def animate(i):
    lines[0].set_data(dataframes[i]["x"], dataframes[i]["y1"])
    lines[1].set_data(dataframes[i]["x"], dataframes[i]["y2"])
    return lines

anim = animation.FuncAnimation(fig, animate, 
           frames=N, interval=20, blit=True)

plt.show()

# %%
import numpy as np
from matplotlib.pyplot import *
import matplotlib.animation as animation
import random
from IPython.display import HTML

dataA = np.random.uniform(0.0001, 0.20, 70000)
dataB = np.random.uniform(0.90, 1.0, 50)
dataC = np.random.uniform(0.10, 0.30, 50)

fig, ax1 = subplots(figsize=(7,5))

# setting the axes
x1 = np.arange(0, len(dataA), 1)
ax1.set_ylabel('Percentage %')
for tl in ax1.get_xticklabels():
    tl.set_color('b')

ax2 = ax1.twiny()
x2 = np.arange(0, len(dataC), 1)
for tl in ax2.get_xticklabels():
    tl.set_color('r')

ax3 = ax1.twiny()
x3 = np.arange(0, len(dataB), 1)
for tl in ax3.get_xticklabels():
    tl.set_color('g')

# set plots
line1, =ax1.plot(x1,dataA, 'b-', label="dataA")
line2, =ax2.plot(x2,dataC, 'r-',label="dataB")
line3, =ax3.plot(x3, dataB, 'g-', label="dataC")

# set legends
ax1.legend([line1, line2, line3], [line1.get_label(),line2.get_label(), line3.get_label()])

def update(num):
    ratio = 70000/50
    i = num/ratio
    line1.set_data(x1[:num], dataA[:num])
    if num % ratio == 0:
        line2.set_data(x2[:i], dataC[:i])
        line3.set_data(x3[:i], dataB[:i])


ani = animation.FuncAnimation(fig, update, interval=5, repeat=False)

HTML(ani.to_html5_video())
# Out:
# <video width="504" height="360" controls autoplay>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %%
import numpy as np 
import pandas as pd
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import matplotlib.animation as animation
# %matplotlib notebook

xmin = 0        # minimum value of x 
xmax = 2        # maximum value of x
N = 200         # Number of nodes  
dt = 0.005      # time step
tmax = 2      # solution time
v = 0.5           # velocity
t0 = 0

# Discritize the domain 
dx = (xmax - xmin)/N
x = np.arange(xmin-dx,xmax+dx,dx)
# set initial condition 
u0 = np.exp(-200*np.square(x-0.25))

u = u0.copy()
unp1 = u0.copy()
unpf = []
uexact = []
t = np.arange(t0, tmax, dt)
#Newman boundary condition no gradient across the boundary 
u[0]= u[2]
u[-1]= u[N-1]
#Loop through time
nsteps = int(tmax/dt)
for n in range (0,nsteps):    
    #Calculate the FOU scheme
    for i in range (1, N+1):
        unp1[i] = u[i] - v*(dt/dx)*(u[i]-u[i-1])
    unpf.append(unp1.copy())
    uexact.append(np.exp(-200*np.square(x-0.25-v*t[n])))
    u = unp1

fig, ax = plt.subplots()

plt.xlabel('x')
plt.ylabel('u')
plt.title('Initial condition')
line, = ax.plot(x, u0)
line2, = ax.plot(x, u0)
def animate(i):
    line.set_ydata(uexact[i])  # update the data
    line2.set_ydata(unpf[i])  # update the data
    return line, line2,

ani = animation.FuncAnimation(fig, animate, np.arange(1, len(unpf)), interval=100)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-184-d1c7059403a6> in <module>()
#      18 # Discritize the domain
#      19 dx = (xmax - xmin)/N
# ---> 20 x = np.arange(xmin-dx,xmax+dx,dx)
#      21 # set initial condition
#      22 u0 = np.exp(-200*np.square(x-0.25))
#
# ZeroDivisionError: division by zero

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

x = np.linspace(0,15,100)

fig = plt.figure()
p1 = fig.add_subplot(111)

p1.set_xlim([0,15])
p1.set_ylim([0,100])

# set up empty lines to be updates later on
l1, = p1.plot([],[],'b')
l2, = p1.plot([],[],'r')

def gen1():
    i = 0.5
    while(True):
        yield i
        i += 0.1

def gen2():
    j = 0
    while(True):
        yield j
        j += 1

def run1(c):
    y = c*x
    l1.set_data(x,y)

def run2(c):
    y = c*x
    l2.set_data(x,y)

ani1 = animation.FuncAnimation(fig,run1,gen1,interval=1000)
ani2 = animation.FuncAnimation(fig,run2,gen2,interval=1000)
plt.show()
