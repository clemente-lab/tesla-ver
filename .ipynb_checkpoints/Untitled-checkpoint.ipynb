# %%
import loclust
from loclust import parse
import numpy as np
import pandas as pd
import plotly.plotly as py
import plotly.figure_factory as ff
from plotly.grid_objs import Grid, Column

def trajectory_to_grid(path, yaxis):
    trajectory = loclust.parse.read_trajectories(path)
    columns_list = list()
    for traj in trajectory:
        #makes list of all potential time values  
        xvalues = traj.time
    return_frame = pd.DataFrame({'xvalues': xvalues})
    for num, traj in enumerate(trajectory):
        #Checks whether or not yaxis is mdata, and assigns appropriate data to the lists
        if yaxis == 'values':
            yvalues = traj.values
            while(len(yvalues) < len(xvalues)):
                yvalues = np.insert(yvalues, 0, None)
            #Appends column titles
            columns_list.append('yvalues' + str(num))
            data_main = {columns_list[num]: yvalues}
            #Creates the dataframe in question
            df_joined = pd.DataFrame(data=data_main)
            #appends the dataframe to the main dataframe
            return_frame = return_frame.join(df_joined)

        elif yaxis in traj.get_mdata():
            yvalues = traj.get_mdata()[yaxis]
            while(len(yvalues) < len(xvalues)):
                yvalues = np.insert(yvalues, 0, None)
            #Appends column titles
            columns_list.append(str(yaxis) + 'values' + str(num))
            data_main = {columns_list[num]: yvalues}
            #Creates the dataframe
            df_joined = pd.DataFrame(data=data_main)
            #Appends to main dataframe
            return_frame = return_frame.join(df_joined)
        else:
            print 'Invalid Yaxis input'
            exit
    grid = Grid([Column(return_frame[column_name], column_name) for column_name in return_frame.columns])
    return return_frame
    
# print trajectory_to_grid('../teslaver/data/CO2_trajs.csv', 'values')

# %%
import loclust
from loclust import parse
import plotly.plotly as py
import numpy as np
import pandas as pd
import time
import plotly.graph_objs as go
from plotly.grid_objs import Grid, Column


sliders_dict = {
    'active': 0,
    'yanchor': 'top',
    'xanchor': 'left',
    'currentvalue': {
        'font': {'size': 20},
        'prefix': 'Year:',
        'visible': True,
        'xanchor': 'right'
    },
    'transition': {'duration': 300, 'easing': 'cubic-in-out'},
    'pad': {'b': 10, 't': 50},
    'len': 0.9,
    'x': 0.1,
    'y': 0,
    'steps': []
}

figure['layout']['updatemenus'] = [
    {
        'buttons': [
            {
                'args': [
                    None,
                    {
                        'frame': {
                            'duration': 500,
                            'redraw': False
                        },
                        'fromcurrent': True,
                        'transition': {
                            'duration': 300,
                            'easing': 'quadratic-in-out'
                        }
                    }
                ],
                'label': 'Play',
                'method': 'animate'
            },
            {
                'args': [[None], {'frame': {'duration': 0,
                                            'redraw': False},
                                  'mode': 'immediate',
                                  'transition': {'duration': 0}}],
                'label': 'Pause',
                'method': 'animate'
            }
        ],
        'direction': 'left',
        'pad': {'r': 10, 't': 87},
        'showactive': True,
        'type': 'buttons',
        'x': 0.1,
        'xanchor': 'right',
        'y': 0,
        'yanchor': 'top'
    }
]

def animate_trajectories(path, graph_title, xaxis_title, yaxis_title, trajectory_title):
    dtfr = trajectory_to_grid(path, yaxis_title)
    
    # Get a list of y values to track
    all_cols = list(filter(lambda x: 'yvalue' in x, dtfr.columns))
    # Get the x values to track    
    years = sorted([str(year) for year in dtfr['xvalues']])
    
    columns = []
    col_name = 'Trajectory Value'
    col_string = '{year}_{traj}_{header}_gapminder_grid'
    # make grid
    for year in years:
        # Group values by year
        dataset_by_year = dtfr[dtfr['xvalues'] == float(year)]
        # For each trajectory
        for trajectory in all_cols:
            # Create a unqiue column name
            column_name = col_string.format(
                year=year, traj=trajectory, header=col_name
            )
            a_column = Column(list(dataset_by_year[trajectory]), column_name)
            columns.append(a_column) 
            
    main_data = Grid(columns)
    url = py.grid_ops.upload(main_data, 'anim_grid'+str(time.time()), auto_open=False)
    figure = {
        'data': [],
        'layout': {},
        'frames': [],
        'config': {'scrollzoom': True}
    }

    # Use pandas dataframe methods to get min/max values
    figure['layout']['xaxis'] = {'range': [dtfr['xvalues'].min(), dtfr['xvalues'].max()],
                                 'title': xaxis_title,
                                 'gridcolor': '#FFFFFF'}
    figure['layout']['yaxis'] = {'title': yaxis_title,
                                 'range': [
                                     dtfr.filter(regex='yvalues*').min(),
                                     dtfr.filter(regex='yvalues*').max()
                                 ]}

    # Iterate through the desired columns
    for col in all_cols:
        column_name = col_string.format(
            year=years[0], traj=trajectory, header=col_name
        )
        data_dict = {
            'xsrc': main_data.get_column_reference('xvalues'),
            'ysrc': main_data.get_column_reference(column_name),
            'mode': 'markers',
            'marker': {
                'sizemode': 'area',
                'sizeref': 200000
            }
        }
        figure['data'].append(data_dict)

    # Create each frame of the animation
    for year in dtfr['xvalues']:
        frame = {
            'data': [],
            'name': str(year)
        }
        # Add the value of each column for the current frame
        for col in all_cols:
            column_name = col_string.format(
                year=year, traj=trajectory, header=col_name
            )
            data_dict = {
                'xsrc': year,
                'ysrc': main_data.get_column_reference(column_name),
                'mode': 'markers',
                'marker': {
                    'sizemode': 'area',
                    'sizeref': 200000
                },
                'name': col
            }
            frame['data'].append(data_dict)

        # Add the frame to the figure
        figure['frames'].append(frame)
        slider_step = {'args': [
            [year],
            {'frame': {'duration': 300, 'redraw': False},
             'mode': 'immediate',
             'transition': {'duration': 300}}
        ],
            'label': year,
            'method': 'animate'}
        sliders_dict['steps'].append(slider_step)

    figure['layout']['sliders'] = [sliders_dict]
    return figure


figure = animate_trajectories('../teslaver/data/CO2_trajs_short.csv', 'testyboi', 'time', 'values', 'spicy bois')
py.icreate_animations(figure, 'anim_grid'+str(time.time()))
# Out:
# ...reading data
# ---------------------------------------------------------------------------
# PlotlyError                               Traceback (most recent call last)
# <ipython-input-20-f6a919ab3fe1> in <module>()
#     166
#     167
# --> 168 figure = animate_trajectories('../teslaver/data/CO2_trajs_short.csv', 'testyboi', 'time', 'values', 'spicy bois')
#     169 py.icreate_animations(figure, 'anim_grid'+str(time.time()))
#
# <ipython-input-20-f6a919ab3fe1> in animate_trajectories(path, graph_title, xaxis_title, yaxis_title, trajectory_title)
#     117         )
#     118         data_dict = {
# --> 119             'xsrc': main_data.get_column_reference('xvalues'),
#     120             'ysrc': main_data.get_column_reference(column_name),
#     121             'mode': 'markers',
#
# /home/david/anaconda3/envs/lodi/lib/python2.7/site-packages/plotly/grid_objs/grid_objs.pyc in get_column_reference(self, column_name)
#     290             raise exceptions.PlotlyError(
#     291                 "Whoops, that column name doesn't match any of the column "
# --> 292                 "names in your grid. You must pick from {cols}".format(cols=col_names)
#     293             )
#     294         return column_id
#
# PlotlyError: Whoops, that column name doesn't match any of the column names in your grid. You must pick from ['1990.0_yvalues0_Trajectory Value_gapminder_grid', '1990.0_yvalues1_Trajectory Value_gapminder_grid', '1990.0_yvalues2_Trajectory Value_gapminder_grid', '1990.0_yvalues3_Trajectory Value_gapminder_grid', '1990.0_yvalues4_Trajectory Value_gapminder_grid', '1990.0_yvalues5_Trajectory Value_gapminder_grid', '1990.0_yvalues6_Trajectory Value_gapminder_grid', '1990.0_yvalues7_Trajectory Value_gapminder_grid', '1990.0_yvalues8_Trajectory Value_gapminder_grid', '1990.0_yvalues9_Trajectory Value_gapminder_grid', '1990.0_yvalues10_Trajectory Value_gapminder_grid', '1990.0_yvalues11_Trajectory Value_gapminder_grid', '1990.0_yvalues12_Trajectory Value_gapminder_grid', '1990.0_yvalues13_Trajectory Value_gapminder_grid', '1990.0_yvalues14_Trajectory Value_gapminder_grid', '1990.0_yvalues15_Trajectory Value_gapminder_grid', '1990.0_yvalues16_Trajectory Value_gapminder_grid', '1990.0_yvalues17_Trajectory Value_gapminder_grid', '1990.0_yvalues18_Trajectory Value_gapminder_grid', '1990.0_yvalues19_Trajectory Value_gapminder_grid', '1990.0_yvalues20_Trajectory Value_gapminder_grid', '1990.0_yvalues21_Trajectory Value_gapminder_grid', '1990.0_yvalues22_Trajectory Value_gapminder_grid', '1990.0_yvalues23_Trajectory Value_gapminder_grid', '1990.0_yvalues24_Trajectory Value_gapminder_grid', '1990.0_yvalues25_Trajectory Value_gapminder_grid', '1990.0_yvalues26_Trajectory Value_gapminder_grid', '1990.0_yvalues27_Trajectory Value_gapminder_grid', '1990.0_yvalues28_Trajectory Value_gapminder_grid', '1990.0_yvalues29_Trajectory Value_gapminder_grid', '1990.0_yvalues30_Trajectory Value_gapminder_grid', '1990.0_yvalues31_Trajectory Value_gapminder_grid', '1990.0_yvalues32_Trajectory Value_gapminder_grid', '1990.0_yvalues33_Trajectory Value_gapminder_grid', '1990.0_yvalues34_Trajectory Value_gapminder_grid', '1990.0_yvalues35_Trajectory Value_gapminder_grid', '1990.0_yvalues36_Trajectory Value_gapminder_grid', '1990.0_yvalues37_Trajectory Value_gapminder_grid', '1990.0_yvalues38_Trajectory Value_gapminder_grid', '1990.0_yvalues39_Trajectory Value_gapminder_grid', '1990.0_yvalues40_Trajectory Value_gapminder_grid', '1990.0_yvalues41_Trajectory Value_gapminder_grid', '1991.0_yvalues0_Trajectory Value_gapminder_grid', '1991.0_yvalues1_Trajectory Value_gapminder_grid', '1991.0_yvalues2_Trajectory Value_gapminder_grid', '1991.0_yvalues3_Trajectory Value_gapminder_grid', '1991.0_yvalues4_Trajectory Value_gapminder_grid', '1991.0_yvalues5_Trajectory Value_gapminder_grid', '1991.0_yvalues6_Trajectory Value_gapminder_grid', '1991.0_yvalues7_Trajectory Value_gapminder_grid', '1991.0_yvalues8_Trajectory Value_gapminder_grid', '1991.0_yvalues9_Trajectory Value_gapminder_grid', '1991.0_yvalues10_Trajectory Value_gapminder_grid', '1991.0_yvalues11_Trajectory Value_gapminder_grid', '1991.0_yvalues12_Trajectory Value_gapminder_grid', '1991.0_yvalues13_Trajectory Value_gapminder_grid', '1991.0_yvalues14_Trajectory Value_gapminder_grid', '1991.0_yvalues15_Trajectory Value_gapminder_grid', '1991.0_yvalues16_Trajectory Value_gapminder_grid', '1991.0_yvalues17_Trajectory Value_gapminder_grid', '1991.0_yvalues18_Trajectory Value_gapminder_grid', '1991.0_yvalues19_Trajectory Value_gapminder_grid', '1991.0_yvalues20_Trajectory Value_gapminder_grid', '1991.0_yvalues21_Trajectory Value_gapminder_grid', '1991.0_yvalues22_Trajectory Value_gapminder_grid', '1991.0_yvalues23_Trajectory Value_gapminder_grid', '1991.0_yvalues24_Trajectory Value_gapminder_grid', '1991.0_yvalues25_Trajectory Value_gapminder_grid', '1991.0_yvalues26_Trajectory Value_gapminder_grid', '1991.0_yvalues27_Trajectory Value_gapminder_grid', '1991.0_yvalues28_Trajectory Value_gapminder_grid', '1991.0_yvalues29_Trajectory Value_gapminder_grid', '1991.0_yvalues30_Trajectory Value_gapminder_grid', '1991.0_yvalues31_Trajectory Value_gapminder_grid', '1991.0_yvalues32_Trajectory Value_gapminder_grid', '1991.0_yv ...
