# %%
import numpy as np
import pandas as pd
import matplotlib
# matplotlib.use('Qt5Agg')
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from teslaver import utilities as utls
from loclust import parse

# %matplotlib notebook
df = utls.trajectories_to_dataframe(trajs=parse.read_trajectories('./data/CO2_trajs.csv'))
groo_X = df.groupby('X')
groo_DET = df.groupby('country_name')

ylim = (min(df['Y']),max(df['Y']))
xlim = (min(groo_X.groups.keys()), (max(groo_X.groups.keys()) + 1))

fig = plt.figure()
ax = plt.axes(xlim=xlim, ylim=ylim)

num_lines = len(groo_DET.groups.keys())
    
lines = [plt.plot([], [])[0] for _ in range(num_lines)] #lines to animate
storage = lines

def init():
    for line in lines:
        line.set_data([], [])
    
    return storage

def animate(i):
    for j, line in enumerate(lines):
        country = groo_DET.groups.keys()[j]
        line.set_data(groo_DET.get_group(country)['X'][0:i+1],
                      groo_DET.get_group(country)['Y'][0:i+1])
    return storage
Writer = animation.writers['ffmpeg']
writer = Writer(fps=20, metadata=dict(artist='Me'), bitrate=1800)

anim = animation.FuncAnimation(fig, animate, init_func = init,
                              frames=1000, interval=20, blit=True, repeat=True)

anim.save('yay.mp4', writer=writer)
# plt.show()
# Out:
# ...reading data
# 4
# 0
# Southern Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 34.0
# ISO 3166-2:AF
# EN.ATM.CO2E.PP.GD
# Afghanistan
# Southern Asia
# AF
# AFG
# 8
# 1
# Southern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 39.0
# ISO 3166-2:AL
# EN.ATM.CO2E.PP.GD
# Albania
# Southern Europe
# AL
# ALB
# 12
# 2
# Northern Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 15.0
# ISO 3166-2:DZ
# EN.ATM.CO2E.PP.GD
# Algeria
# Northern Africa
# DZ
# DZA
# 24
# 3
# Middle Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 17.0
# ISO 3166-2:AO
# EN.ATM.CO2E.PP.GD
# Angola
# Middle Africa
# AO
# AGO
# 28
# 4
# Caribbean
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 29.0
# ISO 3166-2:AG
# EN.ATM.CO2E.PP.GD
# Antigua and Barbuda
# Caribbean
# AG
# ATG
# 32
# 5
# South America
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 5.0
# ISO 3166-2:AR
# EN.ATM.CO2E.PP.GD
# Argentina
# South America
# AR
# ARG
# 51
# 6
# Western Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 145.0
# ISO 3166-2:AM
# EN.ATM.CO2E.PP.GD
# Armenia
# Western Asia
# AM
# ARM
# 36
# 7
# Australia and New Zealand
# Oceania
# CO2 emissions (kg per PPP $ of GDP)
# 9.0
# 53.0
# ISO 3166-2:AU
# EN.ATM.CO2E.PP.GD
# Australia
# Australia and New Zealand
# AU
# AUS
# 40
# 8
# Western Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 155.0
# ISO 3166-2:AT
# EN.ATM.CO2E.PP.GD
# Austria
# Western Europe
# AT
# AUT
# 31
# 6
# Western Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 145.0
# ISO 3166-2:AZ
# EN.ATM.CO2E.PP.GD
# Azerbaijan
# Western Asia
# AZ
# AZE
# 44
# 4
# Caribbean
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 29.0
# ISO 3166-2:BS
# EN.ATM.CO2E.PP.GD
# Bahamas, The
# Caribbean
# BS
# BHS
# 48
# 6
# Western Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 145.0
# ISO 3166-2:BH
# EN.ATM.CO2E.PP.GD
# Bahrain
# Western Asia
# BH
# BHR
# 50
# 0
# Southern Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 34.0
# ISO 3166-2:BD
# EN.ATM.CO2E.PP.GD
# Bangladesh
# Southern Asia
# BD
# BGD
# 52
# 4
# Caribbean
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 29.0
# ISO 3166-2:BB
# EN.ATM.CO2E.PP.GD
# Barbados
# Caribbean
# BB
# BRB
# 112
# 9
# Eastern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 151.0
# ISO 3166-2:BY
# EN.ATM.CO2E.PP.GD
# Belarus
# Eastern Europe
# BY
# BLR
# 56
# 8
# Western Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 155.0
# ISO 3166-2:BE
# EN.ATM.CO2E.PP.GD
# Belgium
# Western Europe
# BE
# BEL
# 84
# 10
# Central America
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 13.0
# ISO 3166-2:BZ
# EN.ATM.CO2E.PP.GD
# Belize
# Central America
# BZ
# BLZ
# 204
# 11
# Western Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 11.0
# ISO 3166-2:BJ
# EN.ATM.CO2E.PP.GD
# Benin
# Western Africa
# BJ
# BEN
# 60
# 12
# Northern America
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 21.0
# ISO 3166-2:BM
# EN.ATM.CO2E.PP.GD
# Bermuda
# Northern America
# BM
# BMU
# 64
# 0
# Southern Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 34.0
# ISO 3166-2:BT
# EN.ATM.CO2E.PP.GD
# Bhutan
# Southern Asia
# BT
# BTN
# 68
# 5
# South America
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 5.0
# ISO 3166-2:BO
# EN.ATM.CO2E.PP.GD
# Bolivia
# South America
# BO
# BOL
# 70
# 1
# Southern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 39.0
# ISO 3166-2:BA
# EN.ATM.CO2E.PP.GD
# Bosnia and Herzegovina
# Southern Europe
# BA
# BIH
# 72
# 13
# Southern Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 18.0
# ISO 3166-2:BW
# EN.ATM.CO2E.PP.GD
# Botswana
# Southern Africa
# BW
# BWA
# 76
# 5
# South America
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 5.0
# ISO 3166-2:BR
# EN.ATM.CO2E.PP.GD
# Brazil
# South America
# BR
# BRA
# 96
# 14
# South-Eastern Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 35.0
# ISO 3166-2:BN
# EN.ATM.CO2E.PP.GD
# Brunei Darussalam
# South-Eastern Asia
# BN
# BRN
# 100
# 9
# Eastern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 151.0
# ISO 3166-2:BG
# EN.ATM.CO2E.PP.GD
# Bulgaria
# Eastern Europe
# BG
# BGR
# 854
# 11
# Western Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 11.0
# ISO 3166-2:BF
# EN.ATM.CO2E.PP.GD
# Burkina Faso
# Western Africa
# BF
# BFA
# 108
# 15
# Eastern Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 14.0
# ISO 3166-2:BI
# EN.ATM.CO2E.PP.GD
# Burundi
# Eastern Africa
# BI
# BDI
# 132
# 11
# Western Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 11.0
# ISO 3166-2:CV
# EN.ATM.CO2E.PP.GD
# Cabo Verde
# Western Africa
# CV
# CPV
# 116
# 14
# South-Eastern Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 35.0
# ISO 3166-2:KH
# EN.ATM.CO2E.PP.GD
# Cambodia
# South-Eastern Asia
# KH
# KHM
# 120
# 3
# Middle Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 17.0
# ISO 3166-2:CM
# EN.ATM.CO2E.PP.GD
# Cameroon
# Middle Africa
# CM
# CMR
# 124
# 12
# Northern America
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 21.0
# ISO 3166-2:CA
# EN.ATM.CO2E.PP.GD
# Canada
# Northern America
# CA
# CAN
# 140
# 3
# Middle Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 17.0
# ISO 3166-2:CF
# EN.ATM.CO2E.PP.GD
# Central African Republic
# Middle Africa
# CF
# CAF
# 148
# 3
# Middle Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 17.0
# ISO 3166-2:TD
# EN.ATM.CO2E.PP.GD
# Chad
# Middle Africa
# TD
# TCD
# 152
# 5
# South America
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 5.0
# ISO 3166-2:CL
# EN.ATM.CO2E.PP.GD
# Chile
# South America
# CL
# CHL
# 156
# 16
# Eastern Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 30.0
# ISO 3166-2:CN
# EN.ATM.CO2E.PP.GD
# China
# Eastern Asia
# CN
# CHN
# 170
# 5
# South America
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 5.0
# ISO 3166-2:CO
# EN.ATM.CO2E.PP.GD
# Colombia
# South America
# CO
# COL
# 174
# 15
# Eastern Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 14.0
# ISO 3166-2:KM
# EN.ATM.CO2E.PP.GD
# Comoros
# Eastern Africa
# KM
# COM
# 180
# 3
# Middle Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 17.0
# ISO 3166-2:CD
# EN.ATM.CO2E.PP.GD
# Congo, Dem. Rep.
# Middle Africa
# CD
# COD
# 178
# 3
# Middle Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 17.0
# ISO 3166-2:CG
# EN.ATM.CO2E.PP.GD
# Congo, Rep.
# Middle Africa
# CG
# COG
# 188
# 10
# Central America
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 13.0
# ISO 3166-2:CR
# EN.ATM.CO2E.PP.GD
# Costa Rica
# Central America
# CR
# CRI
# 384
# 11
# Western Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 11.0
# ISO 3166-2:CI
# EN.ATM.CO2E.PP.GD
# Cote d'Ivoire
# Western Africa
# CI
# CIV
# 191
# 1
# Southern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 39.0
# ISO 3166-2:HR
# EN.ATM.CO2E.PP.GD
# Croatia
# Southern Europe
# HR
# HRV
# 196
# 6
# Western Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 145.0
# ISO 3166-2:CY
# EN.ATM.CO2E.PP.GD
# Cyprus
# Western Asia
# CY
# CYP
# 203
# 9
# Eastern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 151.0
# ISO 3166-2:CZ
# EN.ATM.CO2E.PP.GD
# Czech Republic
# Eastern Europe
# CZ
# CZE
# 208
# 17
# Northern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 154.0
# ISO 3166-2:DK
# EN.ATM.CO2E.PP.GD
# Denmark
# Northern Europe
# DK
# DNK
# 262
# 15
# Eastern Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 14.0
# ISO 3166-2:DJ
# EN.ATM.CO2E.PP.GD
# Djibouti
# Eastern Africa
# DJ
# DJI
# 212
# 4
# Caribbean
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 29.0
# ISO 3166-2:DM
# EN.ATM.CO2E.PP.GD
# Dominica
# Caribbean
# DM
# DMA
# 214
# 4
# Caribbean
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 29.0
# ISO 3166-2:DO
# EN.ATM.CO2E.PP.GD
# Dominican Republic
# Caribbean
# DO
# DOM
# 218
# 5
# South America
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 5.0
# ISO 3166-2:EC
# EN.ATM.CO2E.PP.GD
# Ecuador
# South America
# EC
# ECU
# 818
# 2
# Northern Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 15.0
# ISO 3166-2:EG
# EN.ATM.CO2E.PP.GD
# Egypt, Arab Rep.
# Northern Africa
# EG
# EGY
# 222
# 10
# Central America
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 13.0
# ISO 3166-2:SV
# EN.ATM.CO2E.PP.GD
# El Salvador
# Central America
# SV
# SLV
# 226
# 3
# Middle Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 17.0
# ISO 3166-2:GQ
# EN.ATM.CO2E.PP.GD
# Equatorial Guinea
# Middle Africa
# GQ
# GNQ
# 232
# 15
# Eastern Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 14.0
# ISO 3166-2:ER
# EN.ATM.CO2E.PP.GD
# Eritrea
# Eastern Africa
# ER
# ERI
# 233
# 17
# Northern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 154.0
# ISO 3166-2:EE
# EN.ATM.CO2E.PP.GD
# Estonia
# Northern Europe
# EE
# EST
# 231
# 15
# Eastern Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 14.0
# ISO 3166-2:ET
# EN.ATM.CO2E.PP.GD
# Ethiopia
# Eastern Africa
# ET
# ETH
# 242
# 18
# Melanesia
# Oceania
# CO2 emissions (kg per PPP $ of GDP)
# 9.0
# 54.0
# ISO 3166-2:FJ
# EN.ATM.CO2E.PP.GD
# Fiji
# Melanesia
# FJ
# FJI
# 246
# 17
# Northern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 154.0
# ISO 3166-2:FI
# EN.ATM.CO2E.PP.GD
# Finland
# Northern Europe
# FI
# FIN
# 250
# 8
# Western Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 155.0
# ISO 3166-2:FR
# EN.ATM.CO2E.PP.GD
# France
# Western Europe
# FR
# FRA
# 266
# 3
# Middle Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 17.0
# ISO 3166-2:GA
# EN.ATM.CO2E.PP.GD
# Gabon
# Middle Africa
# GA
# GAB
# 270
# 11
# Western Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 11.0
# ISO 3166-2:GM
# EN.ATM.CO2E.PP.GD
# Gambia, The
# Western Africa
# GM
# GMB
# 268
# 6
# Western Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 145.0
# ISO 3166-2:GE
# EN.ATM.CO2E.PP.GD
# Georgia
# Western Asia
# GE
# GEO
# 276
# 8
# Western Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 155.0
# ISO 3166-2:DE
# EN.ATM.CO2E.PP.GD
# Germany
# Western Europe
# DE
# DEU
# 288
# 11
# Western Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 11.0
# ISO 3166-2:GH
# EN.ATM.CO2E.PP.GD
# Ghana
# Western Africa
# GH
# GHA
# 300
# 1
# Southern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 39.0
# ISO 3166-2:GR
# EN.ATM.CO2E.PP.GD
# Greece
# Southern Europe
# GR
# GRC
# 308
# 4
# Caribbean
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 29.0
# ISO 3166-2:GD
# EN.ATM.CO2E.PP.GD
# Grenada
# Caribbean
# GD
# GRD
# 320
# 10
# Central America
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 13.0
# ISO 3166-2:GT
# EN.ATM.CO2E.PP.GD
# Guatemala
# Central America
# GT
# GTM
# 324
# 11
# Western Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 11.0
# ISO 3166-2:GN
# EN.ATM.CO2E.PP.GD
# Guinea
# Western Africa
# GN
# GIN
# 624
# 11
# Western Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 11.0
# ISO 3166-2:GW
# EN.ATM.CO2E.PP.GD
# Guinea-Bissau
# Western Africa
# GW
# GNB
# 328
# 5
# South America
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 5.0
# ISO 3166-2:GY
# EN.ATM.CO2E.PP.GD
# Guyana
# South America
# GY
# GUY
# 332
# 4
# Caribbean
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 29.0
# ISO 3166-2:HT
# EN.ATM.CO2E.PP.GD
# Haiti
# Caribbean
# HT
# HTI
# 340
# 10
# Central America
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 13.0
# ISO 3166-2:HN
# EN.ATM.CO2E.PP.GD
# Honduras
# Central America
# HN
# HND
# 344
# 16
# Eastern Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 30.0
# ISO 3166-2:HK
# EN.ATM.CO2E.PP.GD
# Hong Kong SAR, China
# Eastern Asia
# HK
# HKG
# 348
# 9
# Eastern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 151.0
# ISO 3166-2:HU
# EN.ATM.CO2E.PP.GD
# Hungary
# Eastern Europe
# HU
# HUN
# 352
# 17
# Northern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 154.0
# ISO 3166-2:IS
# EN.ATM.CO2E.PP.GD
# Iceland
# Northern Europe
# IS
# ISL
# 356
# 0
# Southern Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 34.0
# ISO 3166-2:IN
# EN.ATM.CO2E.PP.GD
# India
# Southern Asia
# IN
# IND
# 360
# 14
# South-Eastern Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 35.0
# ISO 3166-2:ID
# EN.ATM.CO2E.PP.GD
# Indonesia
# South-Eastern Asia
# ID
# IDN
# 364
# 0
# Southern Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 34.0
# ISO 3166-2:IR
# EN.ATM.CO2E.PP.GD
# Iran, Islamic Rep.
# Southern Asia
# IR
# IRN
# 368
# 6
# Western Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 145.0
# ISO 3166-2:IQ
# EN.ATM.CO2E.PP.GD
# Iraq
# Western Asia
# IQ
# IRQ
# 372
# 17
# Northern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 154.0
# ISO 3166-2:IE
# EN.ATM.CO2E.PP.GD
# Ireland
# Northern Europe
# IE
# IRL
# 376
# 6
# Western Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 145.0
# ISO 3166-2:IL
# EN.ATM.CO2E.PP.GD
# Israel
# Western Asia
# IL
# ISR
# 380
# 1
# Southern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 39.0
# ISO 3166-2:IT
# EN.ATM.CO2E.PP.GD
# Italy
# Southern Europe
# IT
# ITA
# 388
# 4
# Caribbean
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 29.0
# ISO 3166-2:JM
# EN.ATM.CO2E.PP.GD
# Jamaica
# Caribbean
# JM
# JAM
# 392
# 16
# Eastern Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 30.0
# ISO 3166-2:JP
# EN.ATM.CO2E.PP.GD
# Japan
# Eastern Asia
# JP
# JPN
# 400
# 6
# Western Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 145.0
# ISO 3166-2:JO
# EN.ATM.CO2E.PP.GD
# Jordan
# Western Asia
# JO
# JOR
# 398
# 19
# Central Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 143.0
# ISO 3166-2:KZ
# EN.ATM.CO2E.PP.GD
# Kazakhstan
# Central Asia
# KZ
# KAZ
# 404
# 15
# Eastern Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 14.0
# ISO 3166-2:KE
# EN.ATM.CO2E.PP.GD
# Kenya
# Eastern Africa
# KE
# KEN
# 296
# 20
# Micronesia
# Oceania
# CO2 emissions (kg per PPP $ of GDP)
# 9.0
# 57.0
# ISO 3166-2:KI
# EN.ATM.CO2E.PP.GD
# Kiribati
# Micronesia
# KI
# KIR
# 410
# 16
# Eastern Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 30.0
# ISO 3166-2:KR
# EN.ATM.CO2E.PP.GD
# Korea, Rep.
# Eastern Asia
# KR
# KOR
# 414
# 6
# Western Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 145.0
# ISO 3166-2:KW
# EN.ATM.CO2E.PP.GD
# Kuwait
# Western Asia
# KW
# KWT
# 417
# 19
# Central Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 143.0
# ISO 3166-2:KG
# EN.ATM.CO2E.PP.GD
# Kyrgyz Republic
# Central Asia
# KG
# KGZ
# 418
# 14
# South-Eastern Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 35.0
# ISO 3166-2:LA
# EN.ATM.CO2E.PP.GD
# Lao PDR
# South-Eastern Asia
# LA
# LAO
# 428
# 17
# Northern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 154.0
# ISO 3166-2:LV
# EN.ATM.CO2E.PP.GD
# Latvia
# Northern Europe
# LV
# LVA
# 422
# 6
# Western Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 145.0
# ISO 3166-2:LB
# EN.ATM.CO2E.PP.GD
# Lebanon
# Western Asia
# LB
# LBN
# 426
# 13
# Southern Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 18.0
# ISO 3166-2:LS
# EN.ATM.CO2E.PP.GD
# Lesotho
# Southern Africa
# LS
# LSO
# 430
# 11
# Western Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 11.0
# ISO 3166-2:LR
# EN.ATM.CO2E.PP.GD
# Liberia
# Western Africa
# LR
# LBR
# 434
# 2
# Northern Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 15.0
# ISO 3166-2:LY
# EN.ATM.CO2E.PP.GD
# Libya
# Northern Africa
# LY
# LBY
# 440
# 17
# Northern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 154.0
# ISO 3166-2:LT
# EN.ATM.CO2E.PP.GD
# Lithuania
# Northern Europe
# LT
# LTU
# 442
# 8
# Western Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 155.0
# ISO 3166-2:LU
# EN.ATM.CO2E.PP.GD
# Luxembourg
# Western Europe
# LU
# LUX
# 446
# 16
# Eastern Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 30.0
# ISO 3166-2:MO
# EN.ATM.CO2E.PP.GD
# Macao SAR, China
# Eastern Asia
# MO
# MAC
# 807
# 1
# Southern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 39.0
# ISO 3166-2:MK
# EN.ATM.CO2E.PP.GD
# Macedonia, FYR
# Southern Europe
# MK
# MKD
# 450
# 15
# Eastern Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 14.0
# ISO 3166-2:MG
# EN.ATM.CO2E.PP.GD
# Madagascar
# Eastern Africa
# MG
# MDG
# 454
# 15
# Eastern Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 14.0
# ISO 3166-2:MW
# EN.ATM.CO2E.PP.GD
# Malawi
# Eastern Africa
# MW
# MWI
# 458
# 14
# South-Eastern Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 35.0
# ISO 3166-2:MY
# EN.ATM.CO2E.PP.GD
# Malaysia
# South-Eastern Asia
# MY
# MYS
# 462
# 0
# Southern Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 34.0
# ISO 3166-2:MV
# EN.ATM.CO2E.PP.GD
# Maldives
# Southern Asia
# MV
# MDV
# 466
# 11
# Western Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 11.0
# ISO 3166-2:ML
# EN.ATM.CO2E.PP.GD
# Mali
# Western Africa
# ML
# MLI
# 470
# 1
# Southern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 39.0
# ISO 3166-2:MT
# EN.ATM.CO2E.PP.GD
# Malta
# Southern Europe
# MT
# MLT
# 584
# 20
# Micronesia
# Oceania
# CO2 emissions (kg per PPP $ of GDP)
# 9.0
# 57.0
# ISO 3166-2:MH
# EN.ATM.CO2E.PP.GD
# Marshall Islands
# Micronesia
# MH
# MHL
# 478
# 11
# Western Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 11.0
# ISO 3166-2:MR
# EN.ATM.CO2E.PP.GD
# Mauritania
# Western Africa
# MR
# MRT
# 480
# 15
# Eastern Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 14.0
# ISO 3166-2:MU
# EN.ATM.CO2E.PP.GD
# Mauritius
# Eastern Africa
# MU
# MUS
# 484
# 10
# Central America
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 13.0
# ISO 3166-2:MX
# EN.ATM.CO2E.PP.GD
# Mexico
# Central America
# MX
# MEX
# 583
# 20
# Micronesia
# Oceania
# CO2 emissions (kg per PPP $ of GDP)
# 9.0
# 57.0
# ISO 3166-2:FM
# EN.ATM.CO2E.PP.GD
# Micronesia, Fed. Sts.
# Micronesia
# FM
# FSM
# 498
# 9
# Eastern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 151.0
# ISO 3166-2:MD
# EN.ATM.CO2E.PP.GD
# Moldova
# Eastern Europe
# MD
# MDA
# 496
# 16
# Eastern Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 30.0
# ISO 3166-2:MN
# EN.ATM.CO2E.PP.GD
# Mongolia
# Eastern Asia
# MN
# MNG
# 499
# 1
# Southern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 39.0
# ISO 3166-2:ME
# EN.ATM.CO2E.PP.GD
# Montenegro
# Southern Europe
# ME
# MNE
# 504
# 2
# Northern Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 15.0
# ISO 3166-2:MA
# EN.ATM.CO2E.PP.GD
# Morocco
# Northern Africa
# MA
# MAR
# 508
# 15
# Eastern Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 14.0
# ISO 3166-2:MZ
# EN.ATM.CO2E.PP.GD
# Mozambique
# Eastern Africa
# MZ
# MOZ
# 104
# 14
# South-Eastern Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 35.0
# ISO 3166-2:MM
# EN.ATM.CO2E.PP.GD
# Myanmar
# South-Eastern Asia
# MM
# MMR
# 516
# 13
# Southern Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 18.0
# ISO 3166-2:NA
# EN.ATM.CO2E.PP.GD
# Namibia
# Southern Africa
# nan
# NAM
# 524
# 0
# Southern Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 34.0
# ISO 3166-2:NP
# EN.ATM.CO2E.PP.GD
# Nepal
# Southern Asia
# NP
# NPL
# 528
# 8
# Western Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 155.0
# ISO 3166-2:NL
# EN.ATM.CO2E.PP.GD
# Netherlands
# Western Europe
# NL
# NLD
# 554
# 7
# Australia and New Zealand
# Oceania
# CO2 emissions (kg per PPP $ of GDP)
# 9.0
# 53.0
# ISO 3166-2:NZ
# EN.ATM.CO2E.PP.GD
# New Zealand
# Australia and New Zealand
# NZ
# NZL
# 558
# 10
# Central America
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 13.0
# ISO 3166-2:NI
# EN.ATM.CO2E.PP.GD
# Nicaragua
# Central America
# NI
# NIC
# 562
# 11
# Western Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 11.0
# ISO 3166-2:NE
# EN.ATM.CO2E.PP.GD
# Niger
# Western Africa
# NE
# NER
# 566
# 11
# Western Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 11.0
# ISO 3166-2:NG
# EN.ATM.CO2E.PP.GD
# Nigeria
# Western Africa
# NG
# NGA
# 578
# 17
# Northern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 154.0
# ISO 3166-2:NO
# EN.ATM.CO2E.PP.GD
# Norway
# Northern Europe
# NO
# NOR
# 512
# 6
# Western Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 145.0
# ISO 3166-2:OM
# EN.ATM.CO2E.PP.GD
# Oman
# Western Asia
# OM
# OMN
# 586
# 0
# Southern Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 34.0
# ISO 3166-2:PK
# EN.ATM.CO2E.PP.GD
# Pakistan
# Southern Asia
# PK
# PAK
# 585
# 20
# Micronesia
# Oceania
# CO2 emissions (kg per PPP $ of GDP)
# 9.0
# 57.0
# ISO 3166-2:PW
# EN.ATM.CO2E.PP.GD
# Palau
# Micronesia
# PW
# PLW
# 591
# 10
# Central America
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 13.0
# ISO 3166-2:PA
# EN.ATM.CO2E.PP.GD
# Panama
# Central America
# PA
# PAN
# 598
# 18
# Melanesia
# Oceania
# CO2 emissions (kg per PPP $ of GDP)
# 9.0
# 54.0
# ISO 3166-2:PG
# EN.ATM.CO2E.PP.GD
# Papua New Guinea
# Melanesia
# PG
# PNG
# 600
# 5
# South America
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 5.0
# ISO 3166-2:PY
# EN.ATM.CO2E.PP.GD
# Paraguay
# South America
# PY
# PRY
# 604
# 5
# South America
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 5.0
# ISO 3166-2:PE
# EN.ATM.CO2E.PP.GD
# Peru
# South America
# PE
# PER
# 608
# 14
# South-Eastern Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 35.0
# ISO 3166-2:PH
# EN.ATM.CO2E.PP.GD
# Philippines
# South-Eastern Asia
# PH
# PHL
# 616
# 9
# Eastern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 151.0
# ISO 3166-2:PL
# EN.ATM.CO2E.PP.GD
# Poland
# Eastern Europe
# PL
# POL
# 620
# 1
# Southern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 39.0
# ISO 3166-2:PT
# EN.ATM.CO2E.PP.GD
# Portugal
# Southern Europe
# PT
# PRT
# 634
# 6
# Western Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 145.0
# ISO 3166-2:QA
# EN.ATM.CO2E.PP.GD
# Qatar
# Western Asia
# QA
# QAT
# 642
# 9
# Eastern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 151.0
# ISO 3166-2:RO
# EN.ATM.CO2E.PP.GD
# Romania
# Eastern Europe
# RO
# ROU
# 643
# 9
# Eastern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 151.0
# ISO 3166-2:RU
# EN.ATM.CO2E.PP.GD
# Russian Federation
# Eastern Europe
# RU
# RUS
# 646
# 15
# Eastern Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 14.0
# ISO 3166-2:RW
# EN.ATM.CO2E.PP.GD
# Rwanda
# Eastern Africa
# RW
# RWA
# 882
# 21
# Polynesia
# Oceania
# CO2 emissions (kg per PPP $ of GDP)
# 9.0
# 61.0
# ISO 3166-2:WS
# EN.ATM.CO2E.PP.GD
# Samoa
# Polynesia
# WS
# WSM
# 678
# 3
# Middle Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 17.0
# ISO 3166-2:ST
# EN.ATM.CO2E.PP.GD
# Sao Tome and Principe
# Middle Africa
# ST
# STP
# 682
# 6
# Western Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 145.0
# ISO 3166-2:SA
# EN.ATM.CO2E.PP.GD
# Saudi Arabia
# Western Asia
# SA
# SAU
# 686
# 11
# Western Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 11.0
# ISO 3166-2:SN
# EN.ATM.CO2E.PP.GD
# Senegal
# Western Africa
# SN
# SEN
# 690
# 15
# Eastern Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 14.0
# ISO 3166-2:SC
# EN.ATM.CO2E.PP.GD
# Seychelles
# Eastern Africa
# SC
# SYC
# 694
# 11
# Western Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 11.0
# ISO 3166-2:SL
# EN.ATM.CO2E.PP.GD
# Sierra Leone
# Western Africa
# SL
# SLE
# 702
# 14
# South-Eastern Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 35.0
# ISO 3166-2:SG
# EN.ATM.CO2E.PP.GD
# Singapore
# South-Eastern Asia
# SG
# SGP
# 703
# 9
# Eastern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 151.0
# ISO 3166-2:SK
# EN.ATM.CO2E.PP.GD
# Slovak Republic
# Eastern Europe
# SK
# SVK
# 705
# 1
# Southern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 39.0
# ISO 3166-2:SI
# EN.ATM.CO2E.PP.GD
# Slovenia
# Southern Europe
# SI
# SVN
# 90
# 18
# Melanesia
# Oceania
# CO2 emissions (kg per PPP $ of GDP)
# 9.0
# 54.0
# ISO 3166-2:SB
# EN.ATM.CO2E.PP.GD
# Solomon Islands
# Melanesia
# SB
# SLB
# 710
# 13
# Southern Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 18.0
# ISO 3166-2:ZA
# EN.ATM.CO2E.PP.GD
# South Africa
# Southern Africa
# ZA
# ZAF
# 724
# 1
# Southern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 39.0
# ISO 3166-2:ES
# EN.ATM.CO2E.PP.GD
# Spain
# Southern Europe
# ES
# ESP
# 144
# 0
# Southern Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 34.0
# ISO 3166-2:LK
# EN.ATM.CO2E.PP.GD
# Sri Lanka
# Southern Asia
# LK
# LKA
# 659
# 4
# Caribbean
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 29.0
# ISO 3166-2:KN
# EN.ATM.CO2E.PP.GD
# St. Kitts and Nevis
# Caribbean
# KN
# KNA
# 662
# 4
# Caribbean
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 29.0
# ISO 3166-2:LC
# EN.ATM.CO2E.PP.GD
# St. Lucia
# Caribbean
# LC
# LCA
# 670
# 4
# Caribbean
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 29.0
# ISO 3166-2:VC
# EN.ATM.CO2E.PP.GD
# St. Vincent and the Grenadines
# Caribbean
# VC
# VCT
# 729
# 2
# Northern Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 15.0
# ISO 3166-2:SD
# EN.ATM.CO2E.PP.GD
# Sudan
# Northern Africa
# SD
# SDN
# 740
# 5
# South America
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 5.0
# ISO 3166-2:SR
# EN.ATM.CO2E.PP.GD
# Suriname
# South America
# SR
# SUR
# 748
# 13
# Southern Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 18.0
# ISO 3166-2:SZ
# EN.ATM.CO2E.PP.GD
# Swaziland
# Southern Africa
# SZ
# SWZ
# 752
# 17
# Northern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 154.0
# ISO 3166-2:SE
# EN.ATM.CO2E.PP.GD
# Sweden
# Northern Europe
# SE
# SWE
# 756
# 8
# Western Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 155.0
# ISO 3166-2:CH
# EN.ATM.CO2E.PP.GD
# Switzerland
# Western Europe
# CH
# CHE
# 762
# 19
# Central Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 143.0
# ISO 3166-2:TJ
# EN.ATM.CO2E.PP.GD
# Tajikistan
# Central Asia
# TJ
# TJK
# 834
# 15
# Eastern Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 14.0
# ISO 3166-2:TZ
# EN.ATM.CO2E.PP.GD
# Tanzania
# Eastern Africa
# TZ
# TZA
# 764
# 14
# South-Eastern Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 35.0
# ISO 3166-2:TH
# EN.ATM.CO2E.PP.GD
# Thailand
# South-Eastern Asia
# TH
# THA
# 626
# 14
# South-Eastern Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 35.0
# ISO 3166-2:TL
# EN.ATM.CO2E.PP.GD
# Timor-Leste
# South-Eastern Asia
# TL
# TLS
# 768
# 11
# Western Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 11.0
# ISO 3166-2:TG
# EN.ATM.CO2E.PP.GD
# Togo
# Western Africa
# TG
# TGO
# 776
# 21
# Polynesia
# Oceania
# CO2 emissions (kg per PPP $ of GDP)
# 9.0
# 61.0
# ISO 3166-2:TO
# EN.ATM.CO2E.PP.GD
# Tonga
# Polynesia
# TO
# TON
# 780
# 4
# Caribbean
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 29.0
# ISO 3166-2:TT
# EN.ATM.CO2E.PP.GD
# Trinidad and Tobago
# Caribbean
# TT
# TTO
# 788
# 2
# Northern Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 15.0
# ISO 3166-2:TN
# EN.ATM.CO2E.PP.GD
# Tunisia
# Northern Africa
# TN
# TUN
# 792
# 6
# Western Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 145.0
# ISO 3166-2:TR
# EN.ATM.CO2E.PP.GD
# Turkey
# Western Asia
# TR
# TUR
# 795
# 19
# Central Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 143.0
# ISO 3166-2:TM
# EN.ATM.CO2E.PP.GD
# Turkmenistan
# Central Asia
# TM
# TKM
# 798
# 21
# Polynesia
# Oceania
# CO2 emissions (kg per PPP $ of GDP)
# 9.0
# 61.0
# ISO 3166-2:TV
# EN.ATM.CO2E.PP.GD
# Tuvalu
# Polynesia
# TV
# TUV
# 800
# 15
# Eastern Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 14.0
# ISO 3166-2:UG
# EN.ATM.CO2E.PP.GD
# Uganda
# Eastern Africa
# UG
# UGA
# 804
# 9
# Eastern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 151.0
# ISO 3166-2:UA
# EN.ATM.CO2E.PP.GD
# Ukraine
# Eastern Europe
# UA
# UKR
# 784
# 6
# Western Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 145.0
# ISO 3166-2:AE
# EN.ATM.CO2E.PP.GD
# United Arab Emirates
# Western Asia
# AE
# ARE
# 826
# 17
# Northern Europe
# Europe
# CO2 emissions (kg per PPP $ of GDP)
# 150.0
# 154.0
# ISO 3166-2:GB
# EN.ATM.CO2E.PP.GD
# United Kingdom
# Northern Europe
# GB
# GBR
# 840
# 12
# Northern America
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 21.0
# ISO 3166-2:US
# EN.ATM.CO2E.PP.GD
# United States
# Northern America
# US
# USA
# 858
# 5
# South America
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 5.0
# ISO 3166-2:UY
# EN.ATM.CO2E.PP.GD
# Uruguay
# South America
# UY
# URY
# 860
# 19
# Central Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 143.0
# ISO 3166-2:UZ
# EN.ATM.CO2E.PP.GD
# Uzbekistan
# Central Asia
# UZ
# UZB
# 548
# 18
# Melanesia
# Oceania
# CO2 emissions (kg per PPP $ of GDP)
# 9.0
# 54.0
# ISO 3166-2:VU
# EN.ATM.CO2E.PP.GD
# Vanuatu
# Melanesia
# VU
# VUT
# 862
# 5
# South America
# Americas
# CO2 emissions (kg per PPP $ of GDP)
# 19.0
# 5.0
# ISO 3166-2:VE
# EN.ATM.CO2E.PP.GD
# Venezuela, RB
# South America
# VE
# VEN
# 704
# 14
# South-Eastern Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 35.0
# ISO 3166-2:VN
# EN.ATM.CO2E.PP.GD
# Vietnam
# South-Eastern Asia
# VN
# VNM
# 887
# 6
# Western Asia
# Asia
# CO2 emissions (kg per PPP $ of GDP)
# 142.0
# 145.0
# ISO 3166-2:YE
# EN.ATM.CO2E.PP.GD
# Yemen, Rep.
# Western Asia
# YE
# YEM
# 894
# 15
# Eastern Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 14.0
# ISO 3166-2:ZM
# EN.ATM.CO2E.PP.GD
# Zambia
# Eastern Africa
# ZM
# ZMB
# 716
# 15
# Eastern Africa
# Africa
# CO2 emissions (kg per PPP $ of GDP)
# 2.0
# 14.0
# ISO 3166-2:ZW
# EN.ATM.CO2E.PP.GD
# Zimbabwe
# Eastern Africa
# ZW
# ZWE
# <div id='0ff457b5-0b19-42c1-b9db-c01292a4dfa1'></div>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-d0f7da69b42f> in <module>()
#      42                               frames=1000, interval=20, blit=True, repeat=True)
#      43
# ---> 44 anim.save('yay.mp4', writer=writer)
#      45 # plt.show()
#
# /Users/alexanderkyim/miniconda3/envs/tslvr/lib/python2.7/site-packages/matplotlib/animation.pyc in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs)
#    1198                         # TODO: See if turning off blit is really necessary
#    1199                         anim._draw_next_frame(d, blit=False)
# -> 1200                     writer.grab_frame(**savefig_kwargs)
#    1201
#    1202         # Reconnect signal for first draw if necessary
#
# /Users/alexanderkyim/miniconda3/envs/tslvr/lib/python2.7/site-packages/matplotlib/animation.pyc in grab_frame(self, **savefig_kwargs)
#     383             # frame format and dpi.
#     384             self.fig.savefig(self._frame_sink(), format=self.frame_format,
# --> 385                              dpi=self.dpi, **savefig_kwargs)
#     386         except (RuntimeError, IOError) as e:
#     387             out, err = self._proc.communicate()
#
# /Users/alexanderkyim/miniconda3/envs/tslvr/lib/python2.7/site-packages/matplotlib/figure.pyc in savefig(self, fname, **kwargs)
#    2060             self.set_frameon(frameon)
#    2061
# -> 2062         self.canvas.print_figure(fname, **kwargs)
#    2063
#    2064         if frameon:
#
# /Users/alexanderkyim/miniconda3/envs/tslvr/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2261                 orientation=orientation,
#    2262                 bbox_inches_restore=_bbox_inches_restore,
# -> 2263                 **kwargs)
#    2264         finally:
#    2265             if bbox_inches and restore_bbox:
#
# /Users/alexanderkyim/miniconda3/envs/tslvr/lib/python2.7/site-packages/matplotlib/backends/backend_agg.pyc in print_raw(self, filename_or_obj, *args, **kwargs)
#     496
#     497     def print_raw(self, filename_or_obj, *args, **kwargs):
# --> 498         FigureCanvasAgg.draw(self)
#     499         renderer = self.get_renderer()
#     500         original_dpi = renderer.dpi
#
# /Users/alexanderkyim/miniconda3/envs/tslvr/lib/python2.7/site-packages/matplotlib/backends/backend_agg.pyc in draw(self)
#     435             # if toolbar:
#     436             #     toolbar.set_cursor(cursors.WAIT)
# --> 437             self.figure.draw(self.renderer)
#     438             # A GUI class may be need to update a window using this draw, so
#     439             # don't forget to call the superclass.
#
# /Users/alexanderkyim/miniconda3/envs/tslvr/lib/python2.7/site-packages/matplotlib/artist.pyc in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# /Users/alexanderkyim/miniconda3/envs/tslvr/lib/python2.7/site-packages/matplotlib/figure.pyc in draw(self, renderer)
#    1491
#    1492             mimage._draw_list_compositing_images(
# -> 1493                 renderer, self, artists, self.suppressComposite)
#    1494
#    1495             renderer.close_group('figure')
#
# /Users/alexanderkyim/miniconda3/envs/tslvr/lib/python2.7/site-packages/matplotlib/image.pyc in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     139     if not_composite or not has_images:
#     140         for a in artists:
# --> 141             a.draw(renderer)
#     142     else:
#     143         # Composite any adjacent images together
#
# /Users/alexanderkyim/miniconda3/envs/tslvr/lib/python2.7/site-packages/matplotlib/artist.pyc in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# /Users/alexanderkyim/miniconda3/envs/tslvr/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in draw(self, renderer, inframe)
#    2633             renderer.stop_rasterizing()
#    2634
# -> 2635         mimage._draw_list_compositing_images(renderer, self, artists)
#    2636
#    2637         renderer.close_group('axes')
#
# /Users/alexanderkyim/miniconda3/envs/tslvr/lib/python2.7/site-packages/matplotlib/image.pyc in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     139     if not_composite or not has_images:
#     140         for a in artists:
# --> 141             a.draw(renderer)
#     142     else:
#     143         # Composite any adjacent images together
#
# /Users/alexanderkyim/miniconda3/envs/tslvr/lib/python2.7/site-packages/matplotlib/artist.pyc in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# /Users/alexanderkyim/miniconda3/envs/tslvr/lib/python2.7/site-packages/matplotlib/axis.pyc in draw(self, renderer, *args, **kwargs)
#    1188         renderer.open_group(__name__)
#    1189
# -> 1190         ticks_to_draw = self._update_ticks(renderer)
#    1191         ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(ticks_to_draw,
#    1192                                                                 renderer)
#
# /Users/alexanderkyim/miniconda3/envs/tslvr/lib/python2.7/site-packages/matplotlib/axis.pyc in _update_ticks(self, renderer)
#    1026
#    1027         interval = self.get_view_interval()
# -> 1028         tick_tups = list(self.iter_ticks())  # iter_ticks calls the locator
#    1029         if self._smart_bounds and tick_tups:
#    1030             # handle inverted limits
#
# /Users/alexanderkyim/miniconda3/envs/tslvr/lib/python2.7/site-packages/matplotlib/axis.pyc in iter_ticks(self)
#     969         Iterate through all of the major and minor ticks.
#     970         """
# --> 971         majorLocs = self.major.locator()
#     972         majorTicks = self.get_major_ticks(len(majorLocs))
#     973         self.major.formatter.set_locs(majorLocs)
#
# /Users/alexanderkyim/miniconda3/envs/tslvr/lib/python2.7/site-packages/matplotlib/ticker.pyc in __call__(self)
#    1952     def __call__(self):
#    1953         vmin, vmax = self.axis.get_view_interval()
# -> 1954         return self.tick_values(vmin, vmax)
#    1955
#    1956     def tick_values(self, vmin, vmax):
#
# /Users/alexanderkyim/miniconda3/envs/tslvr/lib/python2.7/site-packages/matplotlib/ticker.pyc in tick_values(self, vmin, vmax)
#    1960         vmin, vmax = mtransforms.nonsingular(
#    1961             vmin, vmax, expander=1e-13, tiny=1e-14)
# -> 1962         locs = self._raw_ticks(vmin, vmax)
#    1963
#    1964         prune = self._prune
#
# /Users/alexanderkyim/miniconda3/envs/tslvr/lib/python2.7/site-packages/matplotlib/ticker.pyc in _raw_ticks(self, vmin, vmax)
#    1906         if self._nbins == 'auto':
#    1907             if self.axis is not None:
# -> 1908                 nbins = np.clip(self.axis.get_tick_space(),
#    1909                                 max(1, self._min_n_ticks - 1), 9)
#    1910             else:
#
# /Users/alexanderkyim/miniconda3/envs/tslvr/lib/python2.7/site-packages/matplotlib/axis.pyc in get_tick_space(self)
#    2501         ends = self.axes.transAxes.transform([[0, 0], [0, 1]])
#    2502         length = ((ends[1][1] - ends[0][1]) / self.axes.figure.dpi) * 72.0
# -> 2503         tick = self._get_tick(True)
#    2504         # Having a spacing of at least 2 just looks good.
#    2505         size = tick.label1.get_size() * 2.0
#
# /Users/alexanderkyim/miniconda3/envs/tslvr/lib/python2.7/site-packages/matplotlib/axis.pyc in _get_tick(self, major)
#    2162         else:
#    2163             tick_kw = self._minor_tick_kw
# -> 2164         return YTick(self.axes, 0, '', major=major, **tick_kw)
#    2165
#    2166     def _get_label(self):
#
# /Users/alexanderkyim/miniconda3/envs/tslvr/lib/python2.7/site-packages/matplotlib/axis.pyc in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kw)
#     174         self.apply_tickdir(tickdir)
#     175
# --> 176         self.tick1line = self._get_tick1line()
#     177         self.tick2line = self._get_tick2line()
#     178         self.gridline = self._get_gridline()
#
# /Users/alexanderkyim/miniconda3/envs/tslvr/lib/python2.7/site-packages/matplotlib/axis.pyc in _get_tick1line(self)
#     597                           markersize=self._size,
#     598                           markeredgewidth=self._width,
# --> 599                           zorder=self._zorder)
#     600         l.set_transform(self.axes.get_yaxis_transform(which='tick1'))
#     601         self._set_artist_props(l)
#
# /Users/alexanderkyim/miniconda3/envs/tslvr/lib/python2.7/site-packages/matplotlib/lines.pyc in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     419         # update kwargs before updating data to give the caller a
#     420         # chance to init axes (and hence unit support)
# --> 421         self.update(kwargs)
#     422         self.pickradius = pickradius
#     423         self.ind_offset = 0
#
# /Users/alexanderkyim/miniconda3/envs/tslvr/lib/python2.7/site-packages/matplotlib/artist.pyc in update(self, props)
#     890             self.eventson = store
#     891
# --> 892         if len(ret):
#     893             self.pchanged()
#     894             self.stale = True
#
# KeyboardInterrupt:
